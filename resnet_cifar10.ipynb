# %% [markdown]
# # Training ResNet on CIFAR-10
# In this project, you will use the SimpleNN model to perform image classification on CIFAR-10. CIFAR-10 orginally contains 60K images from 10 categories. We split it into 45K/5K/10K images to serve as train/valiation/test set. We only release the ground-truth labels of training/validation dataset to you.

# %% [markdown]
# ## Step 0: Set up the ResNet model
# As you have practiced to implement simple neural networks in Homework 1, we just prepare the implementation for you.

# %%
# import necessary dependencies
import argparse
import os, sys
import time
import datetime
from tqdm import tqdm_notebook as tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.stride = stride

    def forward(self, x):
        residual = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))

        if x.size(1) != out.size(1):
            x = x.to("cpu")
            residual = nn.Conv2d(x.size(1), out.size(1), kernel_size=1, stride=self.stride)(x)
            x = x.to("cuda")
            residual = residual.to("cuda")

        out += residual
        out = F.relu(out)
        return out
    
class ResNet20(nn.Module):
    def __init__(self):
        super(ResNet20, self).__init__()
        self.in_channels = 16
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.bn = nn.BatchNorm2d(16)
        self.stage1 = self._build_blocks(16, 3)
        self.stage2 = self._build_blocks(32, 3, stride=2)
        self.stage3 = self._build_blocks(64, 3, stride=2)
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(64, 10)

    def _build_blocks(self, out_channels, num_blocks, stride=1):
        layers = [ResidualBlock(self.in_channels, out_channels, stride)]
        self.in_channels = out_channels
        for _ in range(1, num_blocks):
            layers.append(ResidualBlock(out_channels, out_channels))
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn(self.conv1(x)))
        out = self.stage1(out)
        out = self.stage2(out)
        out = self.stage3(out)
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# %% [markdown]
# ### Question (a)
# Here is a sanity check to verify the implementation of SimpleNN.
# You need to:
# 1. Write down your code.
# 2. **In the PDF report**, give a brief description on how the code helps you know that SimpleNN is implemented correctly.

# %%
#############################################
# your code here
# sanity check for the correctness of SimpleNN

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using device: ", device)

# Model Definition
net = ResNet20()
net = net.to(device)

# Test forward pass
data = torch.randn(2,3,32,32)
data = data.to(device)
# Forward pass "data" through "net" to get output "out"
out = net(data)

# Check output shape
assert(out.detach().cpu().numpy().shape == (2,10))
print("Forward pass successful")

#############################################
# Out:
# Using device:  cuda
# Forward pass successful

# %% [markdown]
# ## Step 1: Set up preprocessing functions
# Preprocessing is very important as discussed in the lecture.
# You will need to write preprocessing functions with the help of *torchvision.transforms* in this step.
# You can find helpful tutorial/API at [here](https://pytorch.org/vision/stable/transforms.html).

# %% [markdown]
# ### Question (b)
# For the question, you need to:
# 1. Complete the preprocessing code below.
# 2. **In the PDF report**, briefly describe what preprocessing operations you used and what are the purposes of them.
#
# Hint:
# 1. Only two operations are necessary to complete the basic preprocessing here.
# 2. The raw input read from the dataset will be PIL images.
# 3. Data augmentation operations are not mendatory, but feel free to incorporate them if you want.
# 4. Reference value for mean/std of CIFAR-10 images (assuming the pixel values are within [0,1]): mean (RGB-format): (0.4914, 0.4822, 0.4465), std (RGB-format): (0.2023, 0.1994, 0.2010)

# %%
# useful libraries
import torchvision
import torchvision.transforms as transforms

#############################################
# your code here
# specify preprocessing function
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(size = 32, padding = 4),
    transforms.ToTensor(),
    #transforms.RandomErasing(p = 0.4), # play with the value of p
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
#############################################

# %% [markdown]
# ## Step 2: Set up dataset and dataloader
#
# ### Question (c)
# Set up the train/val datasets and dataloders that are to be used during the training. Check out the [official API](https://pytorch.org/docs/stable/data.html) for more information about **torch.utils.data.DataLoader**.
#
# Here, you need to:
# 1. Complete the code below.

# %%
import sys
sys.path.insert(0, "/content/drive/MyDrive/Colab_Notebooks/ECE661/HW2")

# do NOT change these
from tools.dataset import CIFAR10
from torch.utils.data import DataLoader

# a few arguments, do NOT change these
DATA_ROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100

#############################################
# your code here
# construct dataset
train_set = CIFAR10(
    root=DATA_ROOT,
    mode='train',
    download=True,
    transform=transform_train #your code
)
val_set = CIFAR10(
    root=DATA_ROOT,
    mode='val',
    download=True,
    transform=transform_val #your code
)

# construct dataloader
train_loader = DataLoader(
    train_set,
    batch_size= TRAIN_BATCH_SIZE, #your code
    shuffle=True,     # your code
    num_workers=4
)
val_loader = DataLoader(
    val_set,
    batch_size=VAL_BATCH_SIZE,  # your code
    shuffle=True,     # your code
    num_workers=4
)
#############################################
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval_F22.zip
# Extracting ./data/cifar10_trainval_F22.zip to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Step 3: Instantiate your SimpleNN model and deploy it to GPU devices.
# ### Question (d)
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.
#
# Here, you need to:
# 1. Complete the code below.
# 2. **In the PDF report**, briefly describe how you verify that your model is indeed deployed on GPU. (Hint: check $\texttt{nvidia-smi}$.)

# %%
# specify the device for computation
#############################################
# your code here
nn_model = ResNet20()
nn_model = nn_model.to(device) #deploying the model to GPU devices
#############################################

# %%
print("Running on: ", device)
# Out:
# Running on:  cuda

# %%
# !nvidia-smi
# Out:
# Mon Oct  2 01:57:15 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.12             Driver Version: 535.104.12   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-PCIE-16GB           On  | 00000001:00:00.0 Off |                  Off |
# | N/A   29C    P0              40W / 250W |    700MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Step 4: Set up the loss function and optimizer
# Loss function/objective function is used to provide "feedback" for the neural networks. Typically, we use multi-class cross-entropy as the loss function for classification models. As for the optimizer, we will use SGD with momentum.

# %% [markdown]
# ### Question (e)
# Here, you need to:
# 1. Set up the cross-entropy loss as the criterion. (Hint: there are implemented functions in **torch.nn**)
# 2. Specify a SGD optimizer with momentum. (Hint: there are implemented functions in **torch.optim**)

# %%
import torch.nn as nn
import torch.optim as optim

# hyperparameters, do NOT change right now
# initial learning rate
INITIAL_LR = 0.1

# momentum for optimizer
MOMENTUM = 0.9

# L2 regularization strength
REG = 0.0001 # tried 0.0001

#############################################
# your code here
# create loss function
criterion = nn.CrossEntropyLoss()

# Add optimizer
optimizer = optim.SGD(nn_model.parameters(), lr = INITIAL_LR, momentum = MOMENTUM, weight_decay = REG)
#############################################

# %% [markdown]
# ## Step 5: Start the training process.
#
# ### Question (f)/(g)
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
#
# Here you need to:
# 1. Complete the training codes.
# 2. Actually perform the training.
#
# Hint: Training a neural network usually repeats the following 4 steps:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU).**
#
# **ii) Do a forward pass to get the outputs from the neural network and compute the loss. Be careful about your inputs to the loss function. Are the inputs required to be the logits or softmax probabilities? I think it's logits)**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# **iiii) Update the model weights with the optimizer.**
#
# You will also need to compute the accuracy of training/validation samples to track your model's performance over each epoch (the accuracy should be increasing as you train for more and more epochs).

# %%
# some hyperparameters
# total number of training epochs
EPOCHS = 120

# the folder where the trained model is saved
CHECKPOINT_FOLDER = "./saved_model"

# start the training/validation process
# the process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.

DECAY_EPOCHS = EPOCHS // 3 #SELF DEFINED
DECAY = 1/10 #SELF DEFINED

training_losses = []
validation_losses = []
best_val_acc = 0
current_learning_rate = INITIAL_LR

print("==> Buckle up - Training starts!")
print("Learning rate: ", current_learning_rate)
print("="*50)
for i in range(0, EPOCHS):
    # handle the learning rate scheduler.
    if i == 59 or i == 89: #at 50% and 75%
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)

    #######################
    # your code here
    # switch to train mode
    nn_model.train()

    #######################

    print("Epoch %d:" %i)
    # this help you compute the training accuracy
    total_examples = 0
    correct_examples = 0

    train_loss = 0 # track training loss if you want

    # Train the model for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        ####################################
        # your code here
        # copy inputs to device
        inputs, targets = inputs.to(device), targets.to(device)

        # compute the output and loss
        preds = nn_model(inputs)
        loss = criterion(preds, targets)
        train_loss += loss

        # zero the gradient
        optimizer.zero_grad()

        # backpropagation
        loss.backward()

        # apply gradient and update the weights
        optimizer.step()

        # count the number of correctly predicted samples in the current batch
        predicted = torch.argmax(preds, dim = 1)
        correct_examples += (predicted == targets).sum().item()
        total_examples += len(targets)

        ####################################

    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples

    training_losses.append(avg_loss)

    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))

    # Validate on the validation dataset
    #######################
    # your code here
    # switch to eval mode
    nn_model.eval()

    #######################

    # this help you compute the validation accuracy
    total_examples = 0
    correct_examples = 0

    val_loss = 0 # again, track the validation loss if you want

    # disable gradient during validation, which can save GPU memory
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            ####################################
            # your code here
            # copy inputs to device
            inputs, targets = inputs.to(device), targets.to(device)

            # compute the output and loss
            preds = nn_model(inputs)
            loss = criterion(preds, targets)
            val_loss += loss

            # count the number of correctly predicted samples in the current batch
            predicted = torch.argmax(preds, dim = 1)
            correct_examples += (predicted == targets).sum().item()
            total_examples += len(targets)

            ####################################

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples

    validation_losses.append(avg_loss)

    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

    # save the model checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': net.state_dict(),
                'epoch': i,
                'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'simplenn.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f}")
# Out:
# ==> Buckle up - Training starts!
# Learning rate:  0.1
# ==================================================
# Epoch 0:
# Training loss: 1.8537, Training accuracy: 0.2919
# Validation loss: 1.7318, Validation accuracy: 0.3780
# Saving ...
#
# Epoch 1:
# Training loss: 1.3970, Training accuracy: 0.4833
# Validation loss: 1.5142, Validation accuracy: 0.4832
# Saving ...
#
# Epoch 2:
# Training loss: 1.1164, Training accuracy: 0.5952
# Validation loss: 1.1682, Validation accuracy: 0.5936
# Saving ...
#
# Epoch 3:
# Training loss: 0.9503, Training accuracy: 0.6617
# Validation loss: 1.0312, Validation accuracy: 0.6418
# Saving ...
#
# Epoch 4:
# Training loss: 0.8276, Training accuracy: 0.7102
# Validation loss: 0.9582, Validation accuracy: 0.6830
# Saving ...
#
# Epoch 5:
# Training loss: 0.7480, Training accuracy: 0.7392
# Validation loss: 1.1846, Validation accuracy: 0.6362
#
# Epoch 6:
# Training loss: 0.6908, Training accuracy: 0.7601
# Validation loss: 0.8682, Validation accuracy: 0.7168
# Saving ...
#
# Epoch 7:
# Training loss: 0.6526, Training accuracy: 0.7722
# Validation loss: 0.8955, Validation accuracy: 0.7164
#
# Epoch 8:
# Training loss: 0.6141, Training accuracy: 0.7877
# Validation loss: 0.6550, Validation accuracy: 0.7826
# Saving ...
#
# Epoch 9:
# Training loss: 0.5798, Training accuracy: 0.7988
# Validation loss: 0.6971, Validation accuracy: 0.7752
#
# Epoch 10:
# Training loss: 0.5554, Training accuracy: 0.8090
# Validation loss: 0.7149, Validation accuracy: 0.7636
#
# Epoch 11:
# Training loss: 0.5358, Training accuracy: 0.8151
# Validation loss: 0.6624, Validation accuracy: 0.7800
#
# Epoch 12:
# Training loss: 0.5142, Training accuracy: 0.8233
# Validation loss: 0.6411, Validation accuracy: 0.7892
# Saving ...
#
# Epoch 13:
# Training loss: 0.5002, Training accuracy: 0.8284
# Validation loss: 0.6738, Validation accuracy: 0.7754
#
# Epoch 14:
# Training loss: 0.4917, Training accuracy: 0.8291
# Validation loss: 0.6576, Validation accuracy: 0.7860
#
# Epoch 15:
# Training loss: 0.4748, Training accuracy: 0.8359
# Validation loss: 0.6445, Validation accuracy: 0.7878
#
# Epoch 16:
# Training loss: 0.4612, Training accuracy: 0.8421
# Validation loss: 0.6261, Validation accuracy: 0.7936
# Saving ...
#
# Epoch 17:
# Training loss: 0.4585, Training accuracy: 0.8408
# Validation loss: 0.7291, Validation accuracy: 0.7618
#
# Epoch 18:
# Training loss: 0.4449, Training accuracy: 0.8458
# Validation loss: 0.6115, Validation accuracy: 0.7940
# Saving ...
#
# Epoch 19:
# Training loss: 0.4349, Training accuracy: 0.8494
# Validation loss: 0.5335, Validation accuracy: 0.8218
# Saving ...
#
# Epoch 20:
# Training loss: 0.4262, Training accuracy: 0.8524
# Validation loss: 0.6815, Validation accuracy: 0.7822
#
# Epoch 21:
# Training loss: 0.4232, Training accuracy: 0.8528
# Validation loss: 0.7538, Validation accuracy: 0.7754
#
# Epoch 22:
# Training loss: 0.4147, Training accuracy: 0.8553
# Validation loss: 0.5264, Validation accuracy: 0.8254
# Saving ...
#
# Epoch 23:
# Training loss: 0.4084, Training accuracy: 0.8582
# Validation loss: 0.5401, Validation accuracy: 0.8232
#
# Epoch 24:
# Training loss: 0.3971, Training accuracy: 0.8601
# Validation loss: 0.4970, Validation accuracy: 0.8340
# Saving ...
#
# Epoch 25:
# Training loss: 0.3926, Training accuracy: 0.8637
# Validation loss: 0.4902, Validation accuracy: 0.8416
# Saving ...
#
# Epoch 26:
# Training loss: 0.3938, Training accuracy: 0.8648
# Validation loss: 0.6586, Validation accuracy: 0.7844
#
# Epoch 27:
# Training loss: 0.3812, Training accuracy: 0.8673
# Validation loss: 0.5038, Validation accuracy: 0.8348
#
# Epoch 28:
# Training loss: 0.3819, Training accuracy: 0.8669
# Validation loss: 0.5219, Validation accuracy: 0.8190
#
# Epoch 29:
# Training loss: 0.3749, Training accuracy: 0.8709
# Validation loss: 0.5910, Validation accuracy: 0.8186
#
# Epoch 30:
# Training loss: 0.3635, Training accuracy: 0.8739
# Validation loss: 0.5806, Validation accuracy: 0.8144
#
# Epoch 31:
# Training loss: 0.3687, Training accuracy: 0.8729
# Validation loss: 0.7338, Validation accuracy: 0.7794
#
# Epoch 32:
# Training loss: 0.3606, Training accuracy: 0.8748
# Validation loss: 0.5359, Validation accuracy: 0.8278
#
# Epoch 33:
# Training loss: 0.3557, Training accuracy: 0.8760
# Validation loss: 0.5529, Validation accuracy: 0.8290
#
# Epoch 34:
# Training loss: 0.3507, Training accuracy: 0.8776
# Validation loss: 0.5147, Validation accuracy: 0.8360
#
# Epoch 35:
# Training loss: 0.3531, Training accuracy: 0.8767
# Validation loss: 0.5733, Validation accuracy: 0.8136
#
# Epoch 36:
# Training loss: 0.3451, Training accuracy: 0.8819
# Validation loss: 0.6942, Validation accuracy: 0.7934
#
# Epoch 37:
# Training loss: 0.3449, Training accuracy: 0.8795
# Validation loss: 0.6051, Validation accuracy: 0.8080
#
# Epoch 38:
# Training loss: 0.3441, Training accuracy: 0.8801
# Validation loss: 0.5823, Validation accuracy: 0.8184
#
# Epoch 39:
# Training loss: 0.3375, Training accuracy: 0.8821
# Validation loss: 0.5063, Validation accuracy: 0.8374
#
# Epoch 40:
# Training loss: 0.3306, Training accuracy: 0.8831
# Validation loss: 0.6267, Validation accuracy: 0.8120
#
# Epoch 41:
# Training loss: 0.3268, Training accuracy: 0.8869
# Validation loss: 0.5461, Validation accuracy: 0.8236
#
# Epoch 42:
# Training loss: 0.3279, Training accuracy: 0.8850
# Validation loss: 0.4882, Validation accuracy: 0.8454
# Saving ...
#
# Epoch 43:
# Training loss: 0.3291, Training accuracy: 0.8851
# Validation loss: 0.5865, Validation accuracy: 0.8186
#
# Epoch 44:
# Training loss: 0.3225, Training accuracy: 0.8877
# Validation loss: 0.4807, Validation accuracy: 0.8416
#
# Epoch 45:
# Training loss: 0.3280, Training accuracy: 0.8859
# Validation loss: 0.5208, Validation accuracy: 0.8338
#
# Epoch 46:
# Training loss: 0.3187, Training accuracy: 0.8874
# Validation loss: 0.5380, Validation accuracy: 0.8316
#
# Epoch 47:
# Training loss: 0.3194, Training accuracy: 0.8900
# Validation loss: 0.5308, Validation accuracy: 0.8328
#
# Epoch 48:
# Training loss: 0.3174, Training accuracy: 0.8899
# Validation loss: 0.5052, Validation accuracy: 0.8434
#
# Epoch 49:
# Training loss: 0.3143, Training accuracy: 0.8892
# Validation loss: 0.4627, Validation accuracy: 0.8466
# Saving ...
#
# Epoch 50:
# Training loss: 0.3143, Training accuracy: 0.8917
# Validation loss: 0.6195, Validation accuracy: 0.8046
#
# Epoch 51:
# Training loss: 0.3077, Training accuracy: 0.8929
# Validation loss: 0.4817, Validation accuracy: 0.8398
#
# Epoch 52:
# Training loss: 0.3125, Training accuracy: 0.8906
# Validation loss: 0.5181, Validation accuracy: 0.8348
#
# Epoch 53:
# Training loss: 0.3094, Training accuracy: 0.8913
# Validation loss: 0.4778, Validation accuracy: 0.8498
# Saving ...
#
# Epoch 54:
# Training loss: 0.3023, Training accuracy: 0.8933
# Validation loss: 0.5253, Validation accuracy: 0.8354
#
# Epoch 55:
# Training loss: 0.3043, Training accuracy: 0.8950
# Validation loss: 0.4537, Validation accuracy: 0.8538
# Saving ...
#
# Epoch 56:
# Training loss: 0.3026, Training accuracy: 0.8930
# Validation loss: 0.5870, Validation accuracy: 0.8166
#
# Epoch 57:
# Training loss: 0.3012, Training accuracy: 0.8954
# Validation loss: 0.6340, Validation accuracy: 0.8060
#
# Epoch 58:
# Training loss: 0.3039, Training accuracy: 0.8940
# Validation loss: 0.5024, Validation accuracy: 0.8412
#
# Current learning rate has decayed to 0.010000
# Epoch 59:
# Training loss: 0.2096, Training accuracy: 0.9272
# Validation loss: 0.3359, Validation accuracy: 0.8936
# Saving ...
#
# Epoch 60:
# Training loss: 0.1785, Training accuracy: 0.9378
# Validation loss: 0.3239, Validation accuracy: 0.8932
#
# Epoch 61:
# Training loss: 0.1698, Training accuracy: 0.9422
# Validation loss: 0.3172, Validation accuracy: 0.8948
# Saving ...
#
# Epoch 62:
# Training loss: 0.1626, Training accuracy: 0.9445
# Validation loss: 0.3248, Validation accuracy: 0.8992
# Saving ...
#
# Epoch 63:
# Training loss: 0.1538, Training accuracy: 0.9470
# Validation loss: 0.3250, Validation accuracy: 0.8974
#
# Epoch 64:
# Training loss: 0.1495, Training accuracy: 0.9496
# Validation loss: 0.3155, Validation accuracy: 0.9000
# Saving ...
#
# Epoch 65:
# Training loss: 0.1400, Training accuracy: 0.9521
# Validation loss: 0.3296, Validation accuracy: 0.8992
#
# Epoch 66:
# Training loss: 0.1428, Training accuracy: 0.9511
# Validation loss: 0.3240, Validation accuracy: 0.8988
#
# Epoch 67:
# Training loss: 0.1356, Training accuracy: 0.9537
# Validation loss: 0.3295, Validation accuracy: 0.8970
#
# Epoch 68:
# Training loss: 0.1336, Training accuracy: 0.9526
# Validation loss: 0.3118, Validation accuracy: 0.9002
# Saving ...
#
# Epoch 69:
# Training loss: 0.1283, Training accuracy: 0.9556
# Validation loss: 0.3297, Validation accuracy: 0.8972
#
# Epoch 70:
# Training loss: 0.1267, Training accuracy: 0.9561
# Validation loss: 0.3350, Validation accuracy: 0.8970
#
# Epoch 71:
# Training loss: 0.1232, Training accuracy: 0.9576
# Validation loss: 0.3415, Validation accuracy: 0.8986
#
# Epoch 72:
# Training loss: 0.1207, Training accuracy: 0.9574
# Validation loss: 0.3370, Validation accuracy: 0.9010
# Saving ...
#
# Epoch 73:
# Training loss: 0.1218, Training accuracy: 0.9579
# Validation loss: 0.3430, Validation accuracy: 0.9008
#
# Epoch 74:
# Training loss: 0.1191, Training accuracy: 0.9582
# Validation loss: 0.3454, Validation accuracy: 0.8950
#
# Epoch 75:
# Training loss: 0.1128, Training accuracy: 0.9602
# Validation loss: 0.3461, Validation accuracy: 0.8962
#
# Epoch 76:
# Training loss: 0.1116, Training accuracy: 0.9615
# Validation loss: 0.3473, Validation accuracy: 0.9018
# Saving ...
#
# Epoch 77:
# Training loss: 0.1135, Training accuracy: 0.9604
# Validation loss: 0.3470, Validation accuracy: 0.8990
#
# Epoch 78:
# Training loss: 0.1074, Training accuracy: 0.9627
# Validation loss: 0.3669, Validation accuracy: 0.8972
#
# Epoch 79:
# Training loss: 0.1057, Training accuracy: 0.9624
# Validation loss: 0.3442, Validation accuracy: 0.8978
#
# Epoch 80:
# Training loss: 0.1067, Training accuracy: 0.9628
# Validation loss: 0.3468, Validation accuracy: 0.8990
#
# Epoch 81:
# Training loss: 0.1059, Training accuracy: 0.9613
# Validation loss: 0.3582, Validation accuracy: 0.8978
#
# Epoch 82:
# Training loss: 0.1031, Training accuracy: 0.9641
# Validation loss: 0.3479, Validation accuracy: 0.9020
# Saving ...
#
# Epoch 83:
# Training loss: 0.1044, Training accuracy: 0.9637
# Validation loss: 0.3505, Validation accuracy: 0.8974
#
# Epoch 84:
# Training loss: 0.1022, Training accuracy: 0.9643
# Validation loss: 0.3566, Validation accuracy: 0.8994
#
# Epoch 85:
# Training loss: 0.0999, Training accuracy: 0.9660
# Validation loss: 0.3576, Validation accuracy: 0.8936
#
# Epoch 86:
# Training loss: 0.0949, Training accuracy: 0.9670
# Validation loss: 0.3587, Validation accuracy: 0.9000
#
# Epoch 87:
# Training loss: 0.0956, Training accuracy: 0.9661
# Validation loss: 0.3764, Validation accuracy: 0.8990
#
# Epoch 88:
# Training loss: 0.0957, Training accuracy: 0.9662
# Validation loss: 0.3586, Validation accuracy: 0.8990
#
# Current learning rate has decayed to 0.001000
# Epoch 89:
# Training loss: 0.0828, Training accuracy: 0.9721
# Validation loss: 0.3556, Validation accuracy: 0.9028
# Saving ...
#
# Epoch 90:
# Training loss: 0.0790, Training accuracy: 0.9731
# Validation loss: 0.3618, Validation accuracy: 0.8982
#
# Epoch 91:
# Training loss: 0.0784, Training accuracy: 0.9734
# Validation loss: 0.3515, Validation accuracy: 0.8976
#
# Epoch 92:
# Training loss: 0.0804, Training accuracy: 0.9730
# Validation loss: 0.3462, Validation accuracy: 0.9054
# Saving ...
#
# Epoch 93:
# Training loss: 0.0774, Training accuracy: 0.9737
# Validation loss: 0.3526, Validation accuracy: 0.8992
#
# Epoch 94:
# Training loss: 0.0787, Training accuracy: 0.9727
# Validation loss: 0.3621, Validation accuracy: 0.9018
#
# Epoch 95:
# Training loss: 0.0785, Training accuracy: 0.9730
# Validation loss: 0.3615, Validation accuracy: 0.9044
#
# Epoch 96:
# Training loss: 0.0756, Training accuracy: 0.9741
# Validation loss: 0.3634, Validation accuracy: 0.9000
#
# Epoch 97:
# Training loss: 0.0765, Training accuracy: 0.9738
# Validation loss: 0.3580, Validation accuracy: 0.9004
#
# Epoch 98:
# Training loss: 0.0759, Training accuracy: 0.9747
# Validation loss: 0.3522, Validation accuracy: 0.8996
#
# Epoch 99:
# Training loss: 0.0763, Training accuracy: 0.9752
# Validation loss: 0.3595, Validation accuracy: 0.9038
#
# Epoch 100:
# Training loss: 0.0746, Training accuracy: 0.9747
# Validation loss: 0.3602, Validation accuracy: 0.8982
#
# Epoch 101:
# Training loss: 0.0754, Training accuracy: 0.9743
# Validation loss: 0.3589, Validation accuracy: 0.8992
#
# Epoch 102:
# Training loss: 0.0745, Training accuracy: 0.9744
# Validation loss: 0.3597, Validation accuracy: 0.9016
#
# Epoch 103:
# Training loss: 0.0734, Training accuracy: 0.9745
# Validation loss: 0.3653, Validation accuracy: 0.9000
#
# Epoch 104:
# Training loss: 0.0742, Training accuracy: 0.9750
# Validation loss: 0.3713, Validation accuracy: 0.9006
#
# Epoch 105:
# Training loss: 0.0711, Training accuracy: 0.9760
# Validation loss: 0.3601, Validation accuracy: 0.9022
#
# Epoch 106:
# Training loss: 0.0739, Training accuracy: 0.9749
# Validation loss: 0.3632, Validation accuracy: 0.9032
#
# Epoch 107:
# Training loss: 0.0723, Training accuracy: 0.9753
# Validation loss: 0.3563, Validation accuracy: 0.9052
#
# Epoch 108:
# Training loss: 0.0726, Training accuracy: 0.9757
# Validation loss: 0.3453, Validation accuracy: 0.9036
#
# Epoch 109:
# Training loss: 0.0720, Training accuracy: 0.9756
# Validation loss: 0.3552, Validation accuracy: 0.9016
#
# Epoch 110:
# Training loss: 0.0709, Training accuracy: 0.9753
# Validation loss: 0.3478, Validation accuracy: 0.9038
#
# Epoch 111:
# Training loss: 0.0716, Training accuracy: 0.9755
# Validation loss: 0.3751, Validation accuracy: 0.8992
#
# Epoch 112:
# Training loss: 0.0703, Training accuracy: 0.9763
# Validation loss: 0.3674, Validation accuracy: 0.8984
#
# Epoch 113:
# Training loss: 0.0693, Training accuracy: 0.9771
# Validation loss: 0.3689, Validation accuracy: 0.8976
#
# Epoch 114:
# Training loss: 0.0707, Training accuracy: 0.9758
# Validation loss: 0.3643, Validation accuracy: 0.9004
#
# Epoch 115:
# Training loss: 0.0710, Training accuracy: 0.9757
# Validation loss: 0.3583, Validation accuracy: 0.9058
# Saving ...
#
# Epoch 116:
# Training loss: 0.0703, Training accuracy: 0.9763
# Validation loss: 0.3696, Validation accuracy: 0.8996
#
# Epoch 117:
# Training loss: 0.0702, Training accuracy: 0.9754
# Validation loss: 0.3704, Validation accuracy: 0.9008
#
# Epoch 118:
# Training loss: 0.0710, Training accuracy: 0.9758
# Validation loss: 0.3685, Validation accuracy: 0.9028
#
# Epoch 119:
# Training loss: 0.0686, Training accuracy: 0.9772
# Validation loss: 0.3609, Validation accuracy: 0.9028
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9058

# %% [markdown]
# ### Plotting Training and Validation Losses

# %%
tr_losses = [x.item() for x in training_losses]
val_losses = [x.item() for x in validation_losses]
plt.plot(tr_losses, label = 'Training Loss')
plt.plot(val_losses, label = "Validation Loss")
plt.legend()
plt.xlabel("Epoch Num.")
plt.ylabel("Loss")
plt.title("Training & Validation Loss for ResNet-20 For 120 Epochs")
plt.show()
