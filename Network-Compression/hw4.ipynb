# %% [markdown]
# ### Lab2 (a) Model preperation

# %%
from resnet20 import ResNetCIFAR
from train_util import train, finetune, test
import torch
import numpy as np

import time

import torchvision.transforms as transforms
import torchvision
import torch.nn as nn
import torch.optim as optim

from FP_layers import *

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device: ", device)
# Out:
# Device:  cuda

# %%
net = ResNetCIFAR(num_layers=20, Nbits=None)
net = net.to(device)

# %%
# Load the best weight paramters
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=0.3231, Test accuracy=0.9151

# %% [markdown]
# ### Lab2 (b) Prune by percentage

# %%
def prune_by_percentage(layer, q=70.0, device = device):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least 
    significant weight parameters will be pruned.
    """
    # Convert the weight of "layer" to numpy array
    weights = layer.weight.detach().cpu().numpy()
    
    # Compute the q-th percentile of the abs of the converted array
    qth_percentile = np.percentile(np.abs(weights), q)

    # Generate a binary mask same shape as weight to decide which element to prune
    mask = np.where(np.abs(weights) < qth_percentile, 0, np.abs(weights)) #Question: anything smaller than qth_percentile should be pruned right?? 
    mask = np.where(mask != 0, 1, mask)

    # Convert mask to torch tensor and put on GPU
    mask = torch.from_numpy(mask).to(device)

    # Multiply the weight by mask to perform pruning
    layer.weight.data = layer.weight.data * mask
    
    return mask

# %%
#when q = 0.3

net.load_state_dict(torch.load("pretrained_model.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # change q value
        prune_by_percentage(layer, q=30.0)
        
        # Optional: Check the sparsity you achieve in each layer
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np.count_nonzero(np_weight == 0)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.30092592592592593
# Sparsity of body_op.0.conv1.0.conv: 0.2999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.2999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.2999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.2999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.2999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.2999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.3001302083333333
# Sparsity of body_op.3.conv2.0.conv: 0.3000217013888889
# Sparsity of body_op.4.conv1.0.conv: 0.3000217013888889
# Sparsity of body_op.4.conv2.0.conv: 0.3000217013888889
# Sparsity of body_op.5.conv1.0.conv: 0.3000217013888889
# Sparsity of body_op.5.conv2.0.conv: 0.3000217013888889
# Sparsity of body_op.6.conv1.0.conv: 0.3000217013888889
# Sparsity of body_op.6.conv2.0.conv: 0.2999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.2999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.2999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.2999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.2999945746527778
# Sparsity of final_fc.linear: 0.3
# Files already downloaded and verified
# Test Loss=0.3698, Test accuracy=0.9028

# %%
#when q = 0.5

net.load_state_dict(torch.load("pretrained_model.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # change q value
        prune_by_percentage(layer, q=50.0)
        
        # Optional: Check the sparsity you achieve in each layer
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np.count_nonzero(np_weight == 0)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.5
# Sparsity of body_op.0.conv1.0.conv: 0.5
# Sparsity of body_op.0.conv2.0.conv: 0.5
# Sparsity of body_op.1.conv1.0.conv: 0.5
# Sparsity of body_op.1.conv2.0.conv: 0.5
# Sparsity of body_op.2.conv1.0.conv: 0.5
# Sparsity of body_op.2.conv2.0.conv: 0.5
# Sparsity of body_op.3.conv1.0.conv: 0.5
# Sparsity of body_op.3.conv2.0.conv: 0.5
# Sparsity of body_op.4.conv1.0.conv: 0.5
# Sparsity of body_op.4.conv2.0.conv: 0.5
# Sparsity of body_op.5.conv1.0.conv: 0.5
# Sparsity of body_op.5.conv2.0.conv: 0.5
# Sparsity of body_op.6.conv1.0.conv: 0.5
# Sparsity of body_op.6.conv2.0.conv: 0.5
# Sparsity of body_op.7.conv1.0.conv: 0.5
# Sparsity of body_op.7.conv2.0.conv: 0.5
# Sparsity of body_op.8.conv1.0.conv: 0.5
# Sparsity of body_op.8.conv2.0.conv: 0.5
# Sparsity of final_fc.linear: 0.5
# Files already downloaded and verified
# Test Loss=0.6774, Test accuracy=0.8210

# %%
#when q = 0.7

net.load_state_dict(torch.load("pretrained_model.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # change q value
        prune_by_percentage(layer, q=70.0)
        
        # Optional: Check the sparsity you achieve in each layer
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np.count_nonzero(np_weight == 0)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.6990740740740741
# Sparsity of body_op.0.conv1.0.conv: 0.7000868055555556
# Sparsity of body_op.0.conv2.0.conv: 0.7000868055555556
# Sparsity of body_op.1.conv1.0.conv: 0.7000868055555556
# Sparsity of body_op.1.conv2.0.conv: 0.7000868055555556
# Sparsity of body_op.2.conv1.0.conv: 0.7000868055555556
# Sparsity of body_op.2.conv2.0.conv: 0.7000868055555556
# Sparsity of body_op.3.conv1.0.conv: 0.6998697916666666
# Sparsity of body_op.3.conv2.0.conv: 0.6999782986111112
# Sparsity of body_op.4.conv1.0.conv: 0.6999782986111112
# Sparsity of body_op.4.conv2.0.conv: 0.6999782986111112
# Sparsity of body_op.5.conv1.0.conv: 0.6999782986111112
# Sparsity of body_op.5.conv2.0.conv: 0.6999782986111112
# Sparsity of body_op.6.conv1.0.conv: 0.6999782986111112
# Sparsity of body_op.6.conv2.0.conv: 0.7000054253472222
# Sparsity of body_op.7.conv1.0.conv: 0.7000054253472222
# Sparsity of body_op.7.conv2.0.conv: 0.7000054253472222
# Sparsity of body_op.8.conv1.0.conv: 0.7000054253472222
# Sparsity of body_op.8.conv2.0.conv: 0.7000054253472222
# Sparsity of final_fc.linear: 0.7
# Files already downloaded and verified
# Test Loss=2.4417, Test accuracy=0.4204

# %% [markdown]
# ### Lab2 (c) Finetune pruned model

# %%
def finetune_after_prune(net, trainloader, criterion, optimizer, prune=True, global_pruning = False):
    """
    Finetune the pruned model for a single epoch
    Make sure pruned weights are kept as zero
    """
    # Build a dictionary for the nonzero weights
    weight_mask = {}
    
    if global_pruning:
        weight_mask = global_prune_by_percentage(net)
    else:
        for name,layer in net.named_modules():
            if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                # Your code here: generate a mask in GPU torch tensor to have 1 for nonzero element and 0 for zero element
                weight_mask[name] = prune_by_percentage(layer)
    
    global_steps = 0
    train_loss = 0
    correct = 0
    total = 0
    start = time.time()
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = net(inputs)
        optimizer.zero_grad()
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        if prune:
            for name,layer in net.named_modules():
                if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                    # Your code here: Use weight_mask to make sure zero elements remains zero
                    layer.weight.data = layer.weight.data * weight_mask[name]
        
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        global_steps += 1

        if global_steps % 50 == 0:
            end = time.time()
            batch_size = 256
            num_examples_per_second = 50 * batch_size / (end - start)
            print("[Step=%d]\tLoss=%.4f\tacc=%.4f\t%.1f examples/second"
                 % (global_steps, train_loss / (batch_idx + 1), (correct / total), num_examples_per_second))
            start = time.time()

# %%
# Get pruned model
net.load_state_dict(torch.load("pretrained_model.pt"))
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        prune_by_percentage(layer, q=70.0)

# Training setup, do not change
batch_size=256
lr=0.002
reg=1e-4

print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=4)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.875, weight_decay=reg, nesterov=False)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Model finetuning
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    net.train()
    finetune_after_prune(net, trainloader, criterion, optimizer)
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))

    if val_acc > best_acc:
        best_acc = val_acc
        print("Saving...")
        torch.save(net.state_dict(), "net_after_finetune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.4009	acc=0.8620	6673.4 examples/second
# [Step=100]	Loss=0.3559	acc=0.8766	7572.0 examples/second
# [Step=150]	Loss=0.3334	acc=0.8849	7745.7 examples/second
# Test Loss=0.4242, Test acc=0.8682
# Saving...
#
# Epoch: 1
# [Step=50]	Loss=0.2407	acc=0.9161	6385.9 examples/second
# [Step=100]	Loss=0.2427	acc=0.9151	7439.5 examples/second
# [Step=150]	Loss=0.2375	acc=0.9176	7591.7 examples/second
# Test Loss=0.3937, Test acc=0.8771
# Saving...
#
# Epoch: 2
# [Step=50]	Loss=0.2249	acc=0.9197	6591.4 examples/second
# [Step=100]	Loss=0.2194	acc=0.9228	7728.2 examples/second
# [Step=150]	Loss=0.2154	acc=0.9251	7106.3 examples/second
# Test Loss=0.3778, Test acc=0.8808
# Saving...
#
# Epoch: 3
# [Step=50]	Loss=0.1917	acc=0.9341	6720.1 examples/second
# [Step=100]	Loss=0.1950	acc=0.9328	7716.4 examples/second
# [Step=150]	Loss=0.1975	acc=0.9318	7505.5 examples/second
# Test Loss=0.3690, Test acc=0.8820
# Saving...
#
# Epoch: 4
# [Step=50]	Loss=0.1977	acc=0.9303	6248.4 examples/second
# [Step=100]	Loss=0.1940	acc=0.9325	7241.3 examples/second
# [Step=150]	Loss=0.1918	acc=0.9330	7124.4 examples/second
# Test Loss=0.3634, Test acc=0.8850
# Saving...
#
# Epoch: 5
# [Step=50]	Loss=0.1813	acc=0.9355	6735.9 examples/second
# [Step=100]	Loss=0.1817	acc=0.9355	7190.2 examples/second
# [Step=150]	Loss=0.1802	acc=0.9365	7545.0 examples/second
# Test Loss=0.3577, Test acc=0.8861
# Saving...
#
# Epoch: 6
# [Step=50]	Loss=0.1733	acc=0.9409	6020.6 examples/second
# [Step=100]	Loss=0.1733	acc=0.9394	7075.4 examples/second
# [Step=150]	Loss=0.1744	acc=0.9391	7643.6 examples/second
# Test Loss=0.3544, Test acc=0.8877
# Saving...
#
# Epoch: 7
# [Step=50]	Loss=0.1796	acc=0.9361	6811.4 examples/second
# [Step=100]	Loss=0.1735	acc=0.9395	6758.6 examples/second
# [Step=150]	Loss=0.1724	acc=0.9397	7018.2 examples/second
# Test Loss=0.3505, Test acc=0.8885
# Saving...
#
# Epoch: 8
# [Step=50]	Loss=0.1714	acc=0.9398	6395.7 examples/second
# [Step=100]	Loss=0.1714	acc=0.9404	7655.0 examples/second
# [Step=150]	Loss=0.1700	acc=0.9408	7648.3 examples/second
# Test Loss=0.3477, Test acc=0.8892
# Saving...
#
# Epoch: 9
# [Step=50]	Loss=0.1662	acc=0.9423	6775.4 examples/second
# [Step=100]	Loss=0.1644	acc=0.9418	7780.9 examples/second
# [Step=150]	Loss=0.1618	acc=0.9431	7040.2 examples/second
# Test Loss=0.3448, Test acc=0.8908
# Saving...
#
# Epoch: 10
# [Step=50]	Loss=0.1632	acc=0.9426	6786.2 examples/second
# [Step=100]	Loss=0.1591	acc=0.9448	7628.9 examples/second
# [Step=150]	Loss=0.1596	acc=0.9453	7471.6 examples/second
# Test Loss=0.3428, Test acc=0.8897
#
# Epoch: 11
# [Step=50]	Loss=0.1584	acc=0.9457	6663.8 examples/second
# [Step=100]	Loss=0.1560	acc=0.9460	7722.1 examples/second
# [Step=150]	Loss=0.1550	acc=0.9464	7448.6 examples/second
# Test Loss=0.3422, Test acc=0.8917
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.1585	acc=0.9472	6571.9 examples/second
# [Step=100]	Loss=0.1540	acc=0.9484	7669.8 examples/second
# [Step=150]	Loss=0.1551	acc=0.9470	7636.4 examples/second
# Test Loss=0.3425, Test acc=0.8911
#
# Epoch: 13
# [Step=50]	Loss=0.1542	acc=0.9459	6614.6 examples/second
# [Step=100]	Loss=0.1540	acc=0.9471	7541.8 examples/second
# [Step=150]	Loss=0.1521	acc=0.9478	7480.3 examples/second
# Test Loss=0.3397, Test acc=0.8920
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.1474	acc=0.9501	6649.6 examples/second
# [Step=100]	Loss=0.1521	acc=0.9478	7267.7 examples/second
# [Step=150]	Loss=0.1489	acc=0.9490	6964.3 examples/second
# Test Loss=0.3390, Test acc=0.8912
#
# Epoch: 15
# [Step=50]	Loss=0.1469	acc=0.9464	6638.8 examples/second
# [Step=100]	Loss=0.1444	acc=0.9486	7617.3 examples/second
# [Step=150]	Loss=0.1465	acc=0.9487	7237.1 examples/second
# Test Loss=0.3362, Test acc=0.8920
#
# Epoch: 16
# [Step=50]	Loss=0.1548	acc=0.9455	6709.6 examples/second
# [Step=100]	Loss=0.1495	acc=0.9477	7555.2 examples/second
# [Step=150]	Loss=0.1485	acc=0.9481	7746.9 examples/second
# Test Loss=0.3345, Test acc=0.8935
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.1441	acc=0.9520	6575.2 examples/second
# [Step=100]	Loss=0.1452	acc=0.9516	7625.8 examples/second
# [Step=150]	Loss=0.1452	acc=0.9510	7425.3 examples/second
# Test Loss=0.3360, Test acc=0.8943
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.1474	acc=0.9481	6216.3 examples/second
# [Step=100]	Loss=0.1427	acc=0.9496	7220.8 examples/second
# [Step=150]	Loss=0.1419	acc=0.9507	7600.9 examples/second
# Test Loss=0.3337, Test acc=0.8946
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.1407	acc=0.9501	6612.6 examples/second
# [Step=100]	Loss=0.1425	acc=0.9493	7779.0 examples/second
# [Step=150]	Loss=0.1432	acc=0.9497	7704.4 examples/second
# Test Loss=0.3342, Test acc=0.8946

# %%
# Check sparsity of the finetuned model, make sure it's not changed
net.load_state_dict(torch.load("net_after_finetune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np.count_nonzero(np_weight == 0)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.6990740740740741
# Sparsity of body_op.0.conv1.0.conv: 0.7000868055555556
# Sparsity of body_op.0.conv2.0.conv: 0.7000868055555556
# Sparsity of body_op.1.conv1.0.conv: 0.7000868055555556
# Sparsity of body_op.1.conv2.0.conv: 0.7000868055555556
# Sparsity of body_op.2.conv1.0.conv: 0.7000868055555556
# Sparsity of body_op.2.conv2.0.conv: 0.7000868055555556
# Sparsity of body_op.3.conv1.0.conv: 0.6998697916666666
# Sparsity of body_op.3.conv2.0.conv: 0.6999782986111112
# Sparsity of body_op.4.conv1.0.conv: 0.6999782986111112
# Sparsity of body_op.4.conv2.0.conv: 0.6999782986111112
# Sparsity of body_op.5.conv1.0.conv: 0.6999782986111112
# Sparsity of body_op.5.conv2.0.conv: 0.6999782986111112
# Sparsity of body_op.6.conv1.0.conv: 0.6999782986111112
# Sparsity of body_op.6.conv2.0.conv: 0.7000054253472222
# Sparsity of body_op.7.conv1.0.conv: 0.7000054253472222
# Sparsity of body_op.7.conv2.0.conv: 0.7000054253472222
# Sparsity of body_op.8.conv1.0.conv: 0.7000054253472222
# Sparsity of body_op.8.conv2.0.conv: 0.7000054253472222
# Sparsity of final_fc.linear: 0.7
# Files already downloaded and verified
# Test Loss=0.3337, Test accuracy=0.8946

# %% [markdown]
# ### Lab2 (d) Iterative pruning

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    
    net.train()
    if epoch<10:
        for name,layer in net.named_modules():
            if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                # Increase model sparsity
                q = 7 * (epoch + 1) # Question: is it epoch or epoch + 1?
                prune_by_percentage(layer, q=q)
    print("Pruning q: ", q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_iterative_prune.pt")
# Out:
# Epoch: 0
# Pruning q:  7
# [Step=50]	Loss=0.3627	acc=0.8770	6751.9 examples/second
# [Step=100]	Loss=0.3127	acc=0.8925	7704.8 examples/second
# [Step=150]	Loss=0.2850	acc=0.9029	7581.2 examples/second
# Test Loss=0.3843, Test acc=0.8776
#
# Epoch: 1
# Pruning q:  14
# [Step=50]	Loss=0.2657	acc=0.9106	6071.2 examples/second
# [Step=100]	Loss=0.2478	acc=0.9155	6748.5 examples/second
# [Step=150]	Loss=0.2328	acc=0.9199	7451.6 examples/second
# Test Loss=0.3711, Test acc=0.8828
#
# Epoch: 2
# Pruning q:  21
# [Step=50]	Loss=0.2245	acc=0.9224	6580.1 examples/second
# [Step=100]	Loss=0.2190	acc=0.9234	7636.9 examples/second
# [Step=150]	Loss=0.2128	acc=0.9261	7573.4 examples/second
# Test Loss=0.3675, Test acc=0.8853
#
# Epoch: 3
# Pruning q:  28
# [Step=50]	Loss=0.2126	acc=0.9263	6561.1 examples/second
# [Step=100]	Loss=0.2056	acc=0.9291	7504.7 examples/second
# [Step=150]	Loss=0.1995	acc=0.9310	7515.7 examples/second
# Test Loss=0.3591, Test acc=0.8854
#
# Epoch: 4
# Pruning q:  35
# [Step=50]	Loss=0.2057	acc=0.9274	6522.6 examples/second
# [Step=100]	Loss=0.2011	acc=0.9293	7565.4 examples/second
# [Step=150]	Loss=0.1933	acc=0.9325	7189.6 examples/second
# Test Loss=0.3568, Test acc=0.8853
#
# Epoch: 5
# Pruning q:  42
# [Step=50]	Loss=0.1958	acc=0.9319	6563.3 examples/second
# [Step=100]	Loss=0.1865	acc=0.9349	7568.5 examples/second
# [Step=150]	Loss=0.1829	acc=0.9364	7416.4 examples/second
# Test Loss=0.3512, Test acc=0.8860
#
# Epoch: 6
# Pruning q:  49
# [Step=50]	Loss=0.1848	acc=0.9344	6782.0 examples/second
# [Step=100]	Loss=0.1797	acc=0.9365	7622.1 examples/second
# [Step=150]	Loss=0.1774	acc=0.9383	7406.9 examples/second
# Test Loss=0.3482, Test acc=0.8871
#
# Epoch: 7
# Pruning q:  56
# [Step=50]	Loss=0.1711	acc=0.9397	6749.0 examples/second
# [Step=100]	Loss=0.1721	acc=0.9401	7442.0 examples/second
# [Step=150]	Loss=0.1700	acc=0.9413	7357.4 examples/second
# Test Loss=0.3481, Test acc=0.8899
#
# Epoch: 8
# Pruning q:  63
# [Step=50]	Loss=0.1785	acc=0.9370	6642.3 examples/second
# [Step=100]	Loss=0.1726	acc=0.9398	7592.6 examples/second
# [Step=150]	Loss=0.1698	acc=0.9411	7442.0 examples/second
# Test Loss=0.3459, Test acc=0.8894
#
# Epoch: 9
# Pruning q:  70
# [Step=50]	Loss=0.1690	acc=0.9406	6741.3 examples/second
# [Step=100]	Loss=0.1707	acc=0.9406	7530.8 examples/second
# [Step=150]	Loss=0.1691	acc=0.9411	6749.2 examples/second
# Test Loss=0.3495, Test acc=0.8890
#
# Epoch: 10
# Pruning q:  70
# [Step=50]	Loss=0.1565	acc=0.9439	6726.1 examples/second
# [Step=100]	Loss=0.1620	acc=0.9435	7638.1 examples/second
# [Step=150]	Loss=0.1630	acc=0.9432	7461.4 examples/second
# Test Loss=0.3469, Test acc=0.8904
# Saving...
#
# Epoch: 11
# Pruning q:  70
# [Step=50]	Loss=0.1539	acc=0.9480	6645.0 examples/second
# [Step=100]	Loss=0.1599	acc=0.9445	7635.1 examples/second
# [Step=150]	Loss=0.1605	acc=0.9439	7193.5 examples/second
# Test Loss=0.3433, Test acc=0.8909
# Saving...
#
# Epoch: 12
# Pruning q:  70
# [Step=50]	Loss=0.1543	acc=0.9456	6674.5 examples/second
# [Step=100]	Loss=0.1576	acc=0.9449	7697.9 examples/second
# [Step=150]	Loss=0.1567	acc=0.9457	7478.1 examples/second
# Test Loss=0.3410, Test acc=0.8920
# Saving...
#
# Epoch: 13
# Pruning q:  70
# [Step=50]	Loss=0.1475	acc=0.9495	6553.1 examples/second
# [Step=100]	Loss=0.1507	acc=0.9479	7517.4 examples/second
# [Step=150]	Loss=0.1540	acc=0.9467	7735.6 examples/second
# Test Loss=0.3385, Test acc=0.8918
#
# Epoch: 14
# Pruning q:  70
# [Step=50]	Loss=0.1520	acc=0.9484	6665.7 examples/second
# [Step=100]	Loss=0.1512	acc=0.9486	7679.9 examples/second
# [Step=150]	Loss=0.1500	acc=0.9491	7119.7 examples/second
# Test Loss=0.3396, Test acc=0.8930
# Saving...
#
# Epoch: 15
# Pruning q:  70
# [Step=50]	Loss=0.1519	acc=0.9493	6601.6 examples/second
# [Step=100]	Loss=0.1503	acc=0.9498	7547.0 examples/second
# [Step=150]	Loss=0.1511	acc=0.9488	7591.9 examples/second
# Test Loss=0.3371, Test acc=0.8926
#
# Epoch: 16
# Pruning q:  70
# [Step=50]	Loss=0.1470	acc=0.9491	6715.9 examples/second
# [Step=100]	Loss=0.1489	acc=0.9487	7303.9 examples/second
# [Step=150]	Loss=0.1481	acc=0.9486	7205.3 examples/second
# Test Loss=0.3362, Test acc=0.8926
#
# Epoch: 17
# Pruning q:  70
# [Step=50]	Loss=0.1436	acc=0.9516	6608.4 examples/second
# [Step=100]	Loss=0.1418	acc=0.9510	7498.0 examples/second
# [Step=150]	Loss=0.1406	acc=0.9519	7183.4 examples/second
# Test Loss=0.3357, Test acc=0.8947
# Saving...
#
# Epoch: 18
# Pruning q:  70
# [Step=50]	Loss=0.1432	acc=0.9495	6506.9 examples/second
# [Step=100]	Loss=0.1470	acc=0.9488	6998.5 examples/second
# [Step=150]	Loss=0.1428	acc=0.9503	7672.2 examples/second
# Test Loss=0.3362, Test acc=0.8942
#
# Epoch: 19
# Pruning q:  70
# [Step=50]	Loss=0.1418	acc=0.9511	6531.0 examples/second
# [Step=100]	Loss=0.1405	acc=0.9500	7691.6 examples/second
# [Step=150]	Loss=0.1419	acc=0.9500	7605.3 examples/second
# Test Loss=0.3360, Test acc=0.8933

# %%
# Check sparsity of the final model, make sure it's 70%
net.load_state_dict(torch.load("net_after_iterative_prune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here: can copy from previous question
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np.count_nonzero(np_weight == 0)
        # Count number of parameters
        total = np_weight.size
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.6990740740740741
# Sparsity of body_op.0.conv1.0.conv: 0.7000868055555556
# Sparsity of body_op.0.conv2.0.conv: 0.7000868055555556
# Sparsity of body_op.1.conv1.0.conv: 0.7000868055555556
# Sparsity of body_op.1.conv2.0.conv: 0.7000868055555556
# Sparsity of body_op.2.conv1.0.conv: 0.7000868055555556
# Sparsity of body_op.2.conv2.0.conv: 0.7000868055555556
# Sparsity of body_op.3.conv1.0.conv: 0.6998697916666666
# Sparsity of body_op.3.conv2.0.conv: 0.6999782986111112
# Sparsity of body_op.4.conv1.0.conv: 0.6999782986111112
# Sparsity of body_op.4.conv2.0.conv: 0.6999782986111112
# Sparsity of body_op.5.conv1.0.conv: 0.6999782986111112
# Sparsity of body_op.5.conv2.0.conv: 0.6999782986111112
# Sparsity of body_op.6.conv1.0.conv: 0.6999782986111112
# Sparsity of body_op.6.conv2.0.conv: 0.7000054253472222
# Sparsity of body_op.7.conv1.0.conv: 0.7000054253472222
# Sparsity of body_op.7.conv2.0.conv: 0.7000054253472222
# Sparsity of body_op.8.conv1.0.conv: 0.7000054253472222
# Sparsity of body_op.8.conv2.0.conv: 0.7000054253472222
# Sparsity of final_fc.linear: 0.7
# Files already downloaded and verified
# Test Loss=0.3357, Test accuracy=0.8947

# %% [markdown]
# ### Lab2 (e) Global iterative pruning

# %%
def global_prune_by_percentage(net, q=70.0):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least 
    significant weight parameters will be pruned.
    """
    # A list to gather all the weights
    flattened_weights = []
    # Find global pruning threshold
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            weights = layer.weight.detach().cpu().numpy()
            # Flatten the weight and append to flattened_weights
            flattened_weights.append(weights.flatten())
    
    # Concate all weights into a np array
    flattened_weights = np.concatenate(flattened_weights)
    # Find global pruning threshold
    thres = np.percentile(np.abs(flattened_weights), q)
    
    # Apply pruning threshold to all layers
    mask_weights = {}
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            weights = layer.weight.detach().cpu().numpy()
            
            # Generate a binary mask same shape as weight to decide which element to prune
            mask = np.where(np.abs(weights) < thres, 0, np.abs(weights)) #Question: anything smaller than q_th percentile is pruned right?
            mask = np.where(mask != 0, 1, mask)

            # Convert mask to torch tensor and put on GPU
            mask = torch.from_numpy(mask).to(device)
            mask_weights[name] = mask
            
            # Multiply the weight by mask to perform pruning
            layer.weight.data = layer.weight.data * mask
            
    return mask_weights

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    
    net.train()
    # Increase model sparsity
    if epoch<10:
        q=(epoch+1)*7 #question: shouldn't this be *7 instead of *8?? I changed this to 7. Also moved locations for this.
        global_prune_by_percentage(net, q=q)
    print("q %: ", q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False, global_pruning=True)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer, global_pruning = True)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_global_iterative_prune.pt")
# Out:
# Epoch: 0
# q %:  7
# [Step=50]	Loss=0.2202	acc=0.9234	5427.0 examples/second
# [Step=100]	Loss=0.2039	acc=0.9293	7284.7 examples/second
# [Step=150]	Loss=0.1930	acc=0.9332	7872.5 examples/second
# Test Loss=0.3407, Test acc=0.8899
#
# Epoch: 1
# q %:  14
# [Step=50]	Loss=0.1914	acc=0.9342	6742.3 examples/second
# [Step=100]	Loss=0.1811	acc=0.9376	7589.4 examples/second
# [Step=150]	Loss=0.1750	acc=0.9390	7682.1 examples/second
# Test Loss=0.3359, Test acc=0.8924
#
# Epoch: 2
# q %:  21
# [Step=50]	Loss=0.1711	acc=0.9421	6256.6 examples/second
# [Step=100]	Loss=0.1632	acc=0.9449	7700.6 examples/second
# [Step=150]	Loss=0.1623	acc=0.9439	7190.0 examples/second
# Test Loss=0.3325, Test acc=0.8937
#
# Epoch: 3
# q %:  28
# [Step=50]	Loss=0.1712	acc=0.9395	6336.4 examples/second
# [Step=100]	Loss=0.1626	acc=0.9427	7721.0 examples/second
# [Step=150]	Loss=0.1583	acc=0.9445	7575.9 examples/second
# Test Loss=0.3271, Test acc=0.8957
#
# Epoch: 4
# q %:  35
# [Step=50]	Loss=0.1494	acc=0.9486	6455.1 examples/second
# [Step=100]	Loss=0.1494	acc=0.9487	7679.3 examples/second
# [Step=150]	Loss=0.1466	acc=0.9498	7467.5 examples/second
# Test Loss=0.3262, Test acc=0.8945
#
# Epoch: 5
# q %:  42
# [Step=50]	Loss=0.1487	acc=0.9508	6805.2 examples/second
# [Step=100]	Loss=0.1478	acc=0.9500	7657.1 examples/second
# [Step=150]	Loss=0.1450	acc=0.9509	7368.2 examples/second
# Test Loss=0.3254, Test acc=0.8962
#
# Epoch: 6
# q %:  49
# [Step=50]	Loss=0.1462	acc=0.9506	6738.9 examples/second
# [Step=100]	Loss=0.1451	acc=0.9514	7519.0 examples/second
# [Step=150]	Loss=0.1412	acc=0.9525	7651.9 examples/second
# Test Loss=0.3245, Test acc=0.8951
#
# Epoch: 7
# q %:  56
# [Step=50]	Loss=0.1407	acc=0.9534	6783.9 examples/second
# [Step=100]	Loss=0.1391	acc=0.9536	7186.0 examples/second
# [Step=150]	Loss=0.1363	acc=0.9541	7777.9 examples/second
# Test Loss=0.3236, Test acc=0.8967
#
# Epoch: 8
# q %:  63
# [Step=50]	Loss=0.1395	acc=0.9520	6719.5 examples/second
# [Step=100]	Loss=0.1376	acc=0.9528	7331.2 examples/second
# [Step=150]	Loss=0.1371	acc=0.9527	7235.3 examples/second
# Test Loss=0.3194, Test acc=0.8974
#
# Epoch: 9
# q %:  70
# [Step=50]	Loss=0.1369	acc=0.9526	6810.5 examples/second
# [Step=100]	Loss=0.1380	acc=0.9523	7794.9 examples/second
# [Step=150]	Loss=0.1363	acc=0.9529	7849.5 examples/second
# Test Loss=0.3225, Test acc=0.8967
#
# Epoch: 10
# q %:  70
# [Step=50]	Loss=0.1369	acc=0.9530	6813.1 examples/second
# [Step=100]	Loss=0.1357	acc=0.9536	7796.3 examples/second
# [Step=150]	Loss=0.1338	acc=0.9544	7702.9 examples/second
# Test Loss=0.3213, Test acc=0.8963
# Saving...
#
# Epoch: 11
# q %:  70
# [Step=50]	Loss=0.1295	acc=0.9548	6462.8 examples/second
# [Step=100]	Loss=0.1322	acc=0.9550	7614.9 examples/second
# [Step=150]	Loss=0.1325	acc=0.9544	7161.3 examples/second
# Test Loss=0.3185, Test acc=0.8982
# Saving...
#
# Epoch: 12
# q %:  70
# [Step=50]	Loss=0.1295	acc=0.9555	6831.2 examples/second
# [Step=100]	Loss=0.1320	acc=0.9545	7464.2 examples/second
# [Step=150]	Loss=0.1323	acc=0.9543	7360.0 examples/second
# Test Loss=0.3186, Test acc=0.8985
# Saving...
#
# Epoch: 13
# q %:  70
# [Step=50]	Loss=0.1277	acc=0.9561	6414.4 examples/second
# [Step=100]	Loss=0.1272	acc=0.9571	7326.7 examples/second
# [Step=150]	Loss=0.1291	acc=0.9567	7451.6 examples/second
# Test Loss=0.3159, Test acc=0.8992
# Saving...
#
# Epoch: 14
# q %:  70
# [Step=50]	Loss=0.1223	acc=0.9596	6629.2 examples/second
# [Step=100]	Loss=0.1264	acc=0.9571	7839.7 examples/second
# [Step=150]	Loss=0.1270	acc=0.9574	7464.7 examples/second
# Test Loss=0.3138, Test acc=0.8991
#
# Epoch: 15
# q %:  70
# [Step=50]	Loss=0.1275	acc=0.9573	6705.8 examples/second
# [Step=100]	Loss=0.1264	acc=0.9566	7416.1 examples/second
# [Step=150]	Loss=0.1259	acc=0.9570	7531.7 examples/second
# Test Loss=0.3156, Test acc=0.8987
#
# Epoch: 16
# q %:  70
# [Step=50]	Loss=0.1174	acc=0.9584	6788.0 examples/second
# [Step=100]	Loss=0.1216	acc=0.9577	7788.7 examples/second
# [Step=150]	Loss=0.1237	acc=0.9575	7235.9 examples/second
# Test Loss=0.3143, Test acc=0.8997
# Saving...
#
# Epoch: 17
# q %:  70
# [Step=50]	Loss=0.1179	acc=0.9609	6507.2 examples/second
# [Step=100]	Loss=0.1211	acc=0.9594	7290.3 examples/second
# [Step=150]	Loss=0.1214	acc=0.9596	7562.9 examples/second
# Test Loss=0.3147, Test acc=0.8994
#
# Epoch: 18
# q %:  70
# [Step=50]	Loss=0.1262	acc=0.9558	6722.6 examples/second
# [Step=100]	Loss=0.1233	acc=0.9570	7013.5 examples/second
# [Step=150]	Loss=0.1224	acc=0.9580	7786.1 examples/second
# Test Loss=0.3151, Test acc=0.9006
# Saving...
#
# Epoch: 19
# q %:  70
# [Step=50]	Loss=0.1152	acc=0.9609	6735.2 examples/second
# [Step=100]	Loss=0.1206	acc=0.9584	7748.8 examples/second
# [Step=150]	Loss=0.1190	acc=0.9598	7574.6 examples/second
# Test Loss=0.3136, Test acc=0.9002

# %%
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))

zeros_sum = 0
total_sum = 0
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.detach().cpu().numpy()
        # Count number of zeros
        zeros = np.count_nonzero(np_weight == 0)
        # Count number of parameters
        total = np_weight.size
        zeros_sum+=zeros
        total_sum+=total
        print('Sparsity of '+name+': '+str(zeros/total))
print('Total sparsity of: '+str(zeros_sum/total_sum))
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.24305555555555555
# Sparsity of body_op.0.conv1.0.conv: 0.5512152777777778
# Sparsity of body_op.0.conv2.0.conv: 0.5269097222222222
# Sparsity of body_op.1.conv1.0.conv: 0.5199652777777778
# Sparsity of body_op.1.conv2.0.conv: 0.5529513888888888
# Sparsity of body_op.2.conv1.0.conv: 0.5186631944444444
# Sparsity of body_op.2.conv2.0.conv: 0.5655381944444444
# Sparsity of body_op.3.conv1.0.conv: 0.5251736111111112
# Sparsity of body_op.3.conv2.0.conv: 0.5832248263888888
# Sparsity of body_op.4.conv1.0.conv: 0.6157769097222222
# Sparsity of body_op.4.conv2.0.conv: 0.6769748263888888
# Sparsity of body_op.5.conv1.0.conv: 0.6119791666666666
# Sparsity of body_op.5.conv2.0.conv: 0.7030164930555556
# Sparsity of body_op.6.conv1.0.conv: 0.6143120659722222
# Sparsity of body_op.6.conv2.0.conv: 0.6512586805555556
# Sparsity of body_op.7.conv1.0.conv: 0.66259765625
# Sparsity of body_op.7.conv2.0.conv: 0.7189127604166666
# Sparsity of body_op.8.conv1.0.conv: 0.7477213541666666
# Sparsity of body_op.8.conv2.0.conv: 0.9371744791666666
# Sparsity of final_fc.linear: 0.1203125
# Total sparsity of: 0.6999992546657922
# Files already downloaded and verified
# Test Loss=0.3151, Test accuracy=0.9006

# %% [markdown]
# ### Lab 3 (b) and (c): Fixed-point quantization

# %% [markdown]
# b)

# %%
# Define quantized model and load weight

all_nbits = [6, 5, 4, 3, 2]

for Nbits in all_nbits:
    print("Nbits: ", Nbits)
    net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
    net = net.to(device)
    net.load_state_dict(torch.load("pretrained_model.pt"))
    test(net)
    print("-"*50)
# Out:
# Nbits:  6
# Files already downloaded and verified
# Test Loss=0.3364, Test accuracy=0.9145
# --------------------------------------------------
# Nbits:  5
# Files already downloaded and verified
# Test Loss=0.3390, Test accuracy=0.9112
# --------------------------------------------------
# Nbits:  4
# Files already downloaded and verified
# Test Loss=0.3861, Test accuracy=0.8972
# --------------------------------------------------
# Nbits:  3
# Files already downloaded and verified
# Test Loss=0.9874, Test accuracy=0.7662
# --------------------------------------------------
# Nbits:  2
# Files already downloaded and verified
# Test Loss=9.5441, Test accuracy=0.0899
# --------------------------------------------------

# %% [markdown]
# c)

# %%
all_nbits = [4, 3, 2]

for Nbits in all_nbits:
    print("Nbits: ", Nbits)
    net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
    net = net.to(device)
    net.load_state_dict(torch.load("pretrained_model.pt"))
    # Quantized model finetuning
    finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)
    # Load the model with best accuracy
    net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
    test(net)   
    print("-"*50)
# Out:
# Nbits:  4
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=0.0734	acc=0.9753	3210.5 examples/second
# [Step=100]	Loss=0.0686	acc=0.9764	6659.8 examples/second
# [Step=150]	Loss=0.0652	acc=0.9775	6591.1 examples/second
# Test Loss=0.3376, Test acc=0.9091
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.0741	acc=0.9775	3235.1 examples/second
# [Step=250]	Loss=0.0655	acc=0.9766	6534.6 examples/second
# [Step=300]	Loss=0.0635	acc=0.9778	6713.8 examples/second
# [Step=350]	Loss=0.0639	acc=0.9777	6621.2 examples/second
# Test Loss=0.3338, Test acc=0.9097
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.0508	acc=0.9854	3229.2 examples/second
# [Step=450]	Loss=0.0573	acc=0.9802	6428.4 examples/second
# [Step=500]	Loss=0.0597	acc=0.9791	6726.7 examples/second
# [Step=550]	Loss=0.0606	acc=0.9793	6583.4 examples/second
# Test Loss=0.3311, Test acc=0.9114
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.0615	acc=0.9766	3241.8 examples/second
# [Step=650]	Loss=0.0611	acc=0.9796	6571.6 examples/second
# [Step=700]	Loss=0.0607	acc=0.9794	6622.8 examples/second
# [Step=750]	Loss=0.0608	acc=0.9797	6712.6 examples/second
# Test Loss=0.3309, Test acc=0.9122
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=0.0621	acc=0.9802	3211.0 examples/second
# [Step=850]	Loss=0.0597	acc=0.9804	6645.0 examples/second
# [Step=900]	Loss=0.0568	acc=0.9812	6622.2 examples/second
# [Step=950]	Loss=0.0578	acc=0.9809	6627.2 examples/second
# Test Loss=0.3329, Test acc=0.9119
#
# Epoch: 5
# [Step=1000]	Loss=0.0624	acc=0.9811	3236.3 examples/second
# [Step=1050]	Loss=0.0577	acc=0.9815	6435.1 examples/second
# [Step=1100]	Loss=0.0564	acc=0.9818	6677.8 examples/second
# [Step=1150]	Loss=0.0577	acc=0.9813	6701.3 examples/second
# Test Loss=0.3314, Test acc=0.9122
#
# Epoch: 6
# [Step=1200]	Loss=0.0559	acc=0.9829	3190.4 examples/second
# [Step=1250]	Loss=0.0561	acc=0.9822	6526.0 examples/second
# [Step=1300]	Loss=0.0564	acc=0.9819	6570.4 examples/second
# [Step=1350]	Loss=0.0575	acc=0.9814	6716.5 examples/second
# Test Loss=0.3300, Test acc=0.9117
#
# Epoch: 7
# [Step=1400]	Loss=0.0560	acc=0.9817	3230.3 examples/second
# [Step=1450]	Loss=0.0556	acc=0.9813	6777.3 examples/second
# [Step=1500]	Loss=0.0576	acc=0.9808	6633.4 examples/second
# [Step=1550]	Loss=0.0565	acc=0.9812	6741.9 examples/second
# Test Loss=0.3307, Test acc=0.9113
#
# Epoch: 8
# [Step=1600]	Loss=0.0586	acc=0.9794	3215.6 examples/second
# [Step=1650]	Loss=0.0572	acc=0.9814	6771.9 examples/second
# [Step=1700]	Loss=0.0557	acc=0.9821	6396.2 examples/second
# [Step=1750]	Loss=0.0560	acc=0.9815	6734.9 examples/second
# Test Loss=0.3298, Test acc=0.9126
# Saving...
#
# Epoch: 9
# [Step=1800]	Loss=0.0576	acc=0.9827	3204.9 examples/second
# [Step=1850]	Loss=0.0546	acc=0.9826	6614.4 examples/second
# [Step=1900]	Loss=0.0552	acc=0.9822	6404.3 examples/second
# [Step=1950]	Loss=0.0547	acc=0.9823	6324.5 examples/second
# Test Loss=0.3312, Test acc=0.9111
#
# Epoch: 10
# [Step=2000]	Loss=0.0578	acc=0.9815	3272.5 examples/second
# [Step=2050]	Loss=0.0559	acc=0.9817	6595.9 examples/second
# [Step=2100]	Loss=0.0569	acc=0.9808	6659.8 examples/second
# [Step=2150]	Loss=0.0560	acc=0.9813	6408.6 examples/second
# Test Loss=0.3284, Test acc=0.9130
# Saving...
#
# Epoch: 11
# [Step=2200]	Loss=0.0593	acc=0.9806	3183.7 examples/second
# [Step=2250]	Loss=0.0554	acc=0.9818	6684.3 examples/second
# [Step=2300]	Loss=0.0552	acc=0.9816	6634.7 examples/second
# [Step=2350]	Loss=0.0559	acc=0.9812	6632.3 examples/second
# Test Loss=0.3322, Test acc=0.9126
#
# Epoch: 12
# [Step=2400]	Loss=0.0540	acc=0.9832	3207.9 examples/second
# [Step=2450]	Loss=0.0553	acc=0.9823	6655.8 examples/second
# [Step=2500]	Loss=0.0547	acc=0.9819	6423.5 examples/second
# Test Loss=0.3326, Test acc=0.9137
# Saving...
#
# Epoch: 13
# [Step=2550]	Loss=0.0365	acc=0.9863	3192.7 examples/second
# [Step=2600]	Loss=0.0564	acc=0.9809	6572.2 examples/second
# [Step=2650]	Loss=0.0544	acc=0.9822	6599.2 examples/second
# [Step=2700]	Loss=0.0542	acc=0.9825	6550.8 examples/second
# Test Loss=0.3313, Test acc=0.9102
#
# Epoch: 14
# [Step=2750]	Loss=0.0513	acc=0.9811	3258.2 examples/second
# [Step=2800]	Loss=0.0496	acc=0.9839	6591.6 examples/second
# [Step=2850]	Loss=0.0505	acc=0.9836	6725.3 examples/second
# [Step=2900]	Loss=0.0524	acc=0.9828	6587.8 examples/second
# Test Loss=0.3345, Test acc=0.9132
#
# Epoch: 15
# [Step=2950]	Loss=0.0475	acc=0.9863	3267.3 examples/second
# [Step=3000]	Loss=0.0518	acc=0.9839	6309.3 examples/second
# [Step=3050]	Loss=0.0519	acc=0.9837	6670.0 examples/second
# [Step=3100]	Loss=0.0516	acc=0.9835	6646.4 examples/second
# Test Loss=0.3348, Test acc=0.9125
#
# Epoch: 16
# [Step=3150]	Loss=0.0476	acc=0.9838	3201.2 examples/second
# [Step=3200]	Loss=0.0519	acc=0.9836	6501.2 examples/second
# [Step=3250]	Loss=0.0528	acc=0.9826	5558.8 examples/second
# [Step=3300]	Loss=0.0525	acc=0.9830	6467.3 examples/second
# Test Loss=0.3397, Test acc=0.9117
#
# Epoch: 17
# [Step=3350]	Loss=0.0503	acc=0.9829	3147.7 examples/second
# [Step=3400]	Loss=0.0538	acc=0.9824	6437.2 examples/second
# [Step=3450]	Loss=0.0532	acc=0.9829	6319.9 examples/second
# [Step=3500]	Loss=0.0553	acc=0.9818	6653.9 examples/second
# Test Loss=0.3373, Test acc=0.9113
#
# Epoch: 18
# [Step=3550]	Loss=0.0493	acc=0.9837	3203.4 examples/second
# [Step=3600]	Loss=0.0513	acc=0.9826	6642.9 examples/second
# [Step=3650]	Loss=0.0520	acc=0.9833	6641.9 examples/second
# [Step=3700]	Loss=0.0533	acc=0.9828	6565.9 examples/second
# Test Loss=0.3393, Test acc=0.9122
#
# Epoch: 19
# [Step=3750]	Loss=0.0526	acc=0.9820	3141.8 examples/second
# [Step=3800]	Loss=0.0541	acc=0.9818	6485.1 examples/second
# [Step=3850]	Loss=0.0536	acc=0.9821	6363.0 examples/second
# [Step=3900]	Loss=0.0526	acc=0.9825	6203.8 examples/second
# Test Loss=0.3372, Test acc=0.9102
# Files already downloaded and verified
# Test Loss=0.3326, Test accuracy=0.9137
# --------------------------------------------------
# Nbits:  3
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=0.1717	acc=0.9377	5148.5 examples/second
# [Step=100]	Loss=0.1584	acc=0.9435	6530.8 examples/second
# [Step=150]	Loss=0.1525	acc=0.9454	6440.4 examples/second
# Test Loss=0.3935, Test acc=0.8962
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.1212	acc=0.9551	3211.5 examples/second
# [Step=250]	Loss=0.1225	acc=0.9556	6438.7 examples/second
# [Step=300]	Loss=0.1235	acc=0.9561	6546.8 examples/second
# [Step=350]	Loss=0.1222	acc=0.9567	6578.2 examples/second
# Test Loss=0.3777, Test acc=0.8998
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.1152	acc=0.9585	3241.5 examples/second
# [Step=450]	Loss=0.1088	acc=0.9614	6642.7 examples/second
# [Step=500]	Loss=0.1096	acc=0.9604	6514.9 examples/second
# [Step=550]	Loss=0.1093	acc=0.9609	6468.3 examples/second
# Test Loss=0.3760, Test acc=0.8988
#
# Epoch: 3
# [Step=600]	Loss=0.1028	acc=0.9642	3271.4 examples/second
# [Step=650]	Loss=0.1061	acc=0.9618	6585.0 examples/second
# [Step=700]	Loss=0.1085	acc=0.9612	6586.9 examples/second
# [Step=750]	Loss=0.1067	acc=0.9615	6611.2 examples/second
# Test Loss=0.3729, Test acc=0.8992
#
# Epoch: 4
# [Step=800]	Loss=0.1084	acc=0.9617	3194.7 examples/second
# [Step=850]	Loss=0.1034	acc=0.9614	6317.3 examples/second
# [Step=900]	Loss=0.1069	acc=0.9607	6582.8 examples/second
# [Step=950]	Loss=0.1038	acc=0.9625	6729.3 examples/second
# Test Loss=0.3663, Test acc=0.9013
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.1000	acc=0.9629	3158.6 examples/second
# [Step=1050]	Loss=0.1034	acc=0.9620	6739.0 examples/second
# [Step=1100]	Loss=0.1013	acc=0.9628	6237.7 examples/second
# [Step=1150]	Loss=0.1004	acc=0.9639	6543.9 examples/second
# Test Loss=0.3663, Test acc=0.9013
#
# Epoch: 6
# [Step=1200]	Loss=0.1019	acc=0.9632	3213.1 examples/second
# [Step=1250]	Loss=0.1016	acc=0.9626	6487.1 examples/second
# [Step=1300]	Loss=0.1005	acc=0.9631	6622.8 examples/second
# [Step=1350]	Loss=0.1007	acc=0.9630	6561.7 examples/second
# Test Loss=0.3641, Test acc=0.9018
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=0.0884	acc=0.9676	3164.8 examples/second
# [Step=1450]	Loss=0.0945	acc=0.9652	6498.0 examples/second
# [Step=1500]	Loss=0.0938	acc=0.9655	6585.6 examples/second
# [Step=1550]	Loss=0.0940	acc=0.9656	6503.0 examples/second
# Test Loss=0.3596, Test acc=0.9052
# Saving...
#
# Epoch: 8
# [Step=1600]	Loss=0.0886	acc=0.9686	3167.9 examples/second
# [Step=1650]	Loss=0.0907	acc=0.9682	6566.4 examples/second
# [Step=1700]	Loss=0.0919	acc=0.9669	6537.9 examples/second
# [Step=1750]	Loss=0.0934	acc=0.9664	6599.5 examples/second
# Test Loss=0.3660, Test acc=0.9024
#
# Epoch: 9
# [Step=1800]	Loss=0.0878	acc=0.9691	3171.0 examples/second
# [Step=1850]	Loss=0.0946	acc=0.9663	6495.8 examples/second
# [Step=1900]	Loss=0.0956	acc=0.9659	6646.1 examples/second
# [Step=1950]	Loss=0.0955	acc=0.9657	6682.7 examples/second
# Test Loss=0.3645, Test acc=0.9044
#
# Epoch: 10
# [Step=2000]	Loss=0.0954	acc=0.9687	3217.4 examples/second
# [Step=2050]	Loss=0.0981	acc=0.9662	6483.4 examples/second
# [Step=2100]	Loss=0.0941	acc=0.9677	6507.9 examples/second
# [Step=2150]	Loss=0.0944	acc=0.9674	6669.3 examples/second
# Test Loss=0.3617, Test acc=0.9039
#
# Epoch: 11
# [Step=2200]	Loss=0.0907	acc=0.9678	3204.6 examples/second
# [Step=2250]	Loss=0.0910	acc=0.9682	6746.6 examples/second
# [Step=2300]	Loss=0.0910	acc=0.9678	6422.5 examples/second
# [Step=2350]	Loss=0.0904	acc=0.9683	6723.6 examples/second
# Test Loss=0.3578, Test acc=0.9047
#
# Epoch: 12
# [Step=2400]	Loss=0.0894	acc=0.9695	3212.5 examples/second
# [Step=2450]	Loss=0.0905	acc=0.9679	6612.7 examples/second
# [Step=2500]	Loss=0.0902	acc=0.9685	6663.0 examples/second
# Test Loss=0.3632, Test acc=0.9015
#
# Epoch: 13
# [Step=2550]	Loss=0.0886	acc=0.9629	3295.8 examples/second
# [Step=2600]	Loss=0.0860	acc=0.9691	6450.7 examples/second
# [Step=2650]	Loss=0.0867	acc=0.9695	6711.9 examples/second
# [Step=2700]	Loss=0.0881	acc=0.9685	6751.6 examples/second
# Test Loss=0.3585, Test acc=0.9021
#
# Epoch: 14
# [Step=2750]	Loss=0.0771	acc=0.9740	3224.9 examples/second
# [Step=2800]	Loss=0.0837	acc=0.9713	6403.0 examples/second
# [Step=2850]	Loss=0.0877	acc=0.9706	6556.1 examples/second
# [Step=2900]	Loss=0.0892	acc=0.9702	6661.8 examples/second
# Test Loss=0.3507, Test acc=0.9045
#
# Epoch: 15
# [Step=2950]	Loss=0.1007	acc=0.9605	3194.5 examples/second
# [Step=3000]	Loss=0.0879	acc=0.9688	6639.5 examples/second
# [Step=3050]	Loss=0.0886	acc=0.9685	6553.4 examples/second
# [Step=3100]	Loss=0.0881	acc=0.9688	6536.5 examples/second
# Test Loss=0.3635, Test acc=0.9027
#
# Epoch: 16
# [Step=3150]	Loss=0.0892	acc=0.9696	3279.3 examples/second
# [Step=3200]	Loss=0.0869	acc=0.9700	6459.5 examples/second
# [Step=3250]	Loss=0.0840	acc=0.9708	6593.0 examples/second
# [Step=3300]	Loss=0.0880	acc=0.9690	6561.7 examples/second
# Test Loss=0.3530, Test acc=0.9050
#
# Epoch: 17
# [Step=3350]	Loss=0.0792	acc=0.9703	3211.4 examples/second
# [Step=3400]	Loss=0.0822	acc=0.9706	6490.2 examples/second
# [Step=3450]	Loss=0.0835	acc=0.9694	6570.4 examples/second
# [Step=3500]	Loss=0.0855	acc=0.9690	6611.1 examples/second
# Test Loss=0.3484, Test acc=0.9033
#
# Epoch: 18
# [Step=3550]	Loss=0.0838	acc=0.9705	3246.2 examples/second
# [Step=3600]	Loss=0.0868	acc=0.9699	6666.5 examples/second
# [Step=3650]	Loss=0.0858	acc=0.9699	6606.5 examples/second
# [Step=3700]	Loss=0.0875	acc=0.9697	6683.7 examples/second
# Test Loss=0.3690, Test acc=0.9013
#
# Epoch: 19
# [Step=3750]	Loss=0.0888	acc=0.9684	3226.9 examples/second
# [Step=3800]	Loss=0.0871	acc=0.9681	6669.5 examples/second
# [Step=3850]	Loss=0.0874	acc=0.9689	6564.8 examples/second
# [Step=3900]	Loss=0.0881	acc=0.9688	6709.9 examples/second
# Test Loss=0.3649, Test acc=0.9015
# Files already downloaded and verified
# Test Loss=0.3596, Test accuracy=0.9052
# --------------------------------------------------
# Nbits:  2
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=1.3140	acc=0.6275	5848.6 examples/second
# [Step=100]	Loss=1.0522	acc=0.6869	6637.4 examples/second
# [Step=150]	Loss=0.9366	acc=0.7145	6494.0 examples/second
# Test Loss=0.7619, Test acc=0.7735
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.6766	acc=0.7656	3223.0 examples/second
# [Step=250]	Loss=0.5678	acc=0.8060	6598.7 examples/second
# [Step=300]	Loss=0.5543	acc=0.8116	6698.8 examples/second
# [Step=350]	Loss=0.5362	acc=0.8181	6541.9 examples/second
# Test Loss=0.6447, Test acc=0.8021
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.5110	acc=0.8237	3215.4 examples/second
# [Step=450]	Loss=0.4737	acc=0.8346	6594.4 examples/second
# [Step=500]	Loss=0.4681	acc=0.8375	6676.5 examples/second
# [Step=550]	Loss=0.4632	acc=0.8391	6589.2 examples/second
# Test Loss=0.5765, Test acc=0.8243
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.4247	acc=0.8457	3217.9 examples/second
# [Step=650]	Loss=0.4232	acc=0.8521	6523.1 examples/second
# [Step=700]	Loss=0.4195	acc=0.8535	6489.6 examples/second
# [Step=750]	Loss=0.4197	acc=0.8537	6528.9 examples/second
# Test Loss=0.6009, Test acc=0.8173
#
# Epoch: 4
# [Step=800]	Loss=0.3882	acc=0.8625	3221.3 examples/second
# [Step=850]	Loss=0.4052	acc=0.8595	6695.4 examples/second
# [Step=900]	Loss=0.4055	acc=0.8593	6678.8 examples/second
# [Step=950]	Loss=0.4023	acc=0.8608	6607.7 examples/second
# Test Loss=0.5517, Test acc=0.8313
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.3768	acc=0.8678	3231.6 examples/second
# [Step=1050]	Loss=0.3768	acc=0.8672	6553.5 examples/second
# [Step=1100]	Loss=0.3814	acc=0.8666	6637.4 examples/second
# [Step=1150]	Loss=0.3798	acc=0.8673	6690.7 examples/second
# Test Loss=0.5341, Test acc=0.8358
# Saving...
#
# Epoch: 6
# [Step=1200]	Loss=0.3663	acc=0.8709	3192.9 examples/second
# [Step=1250]	Loss=0.3658	acc=0.8725	6592.6 examples/second
# [Step=1300]	Loss=0.3635	acc=0.8738	6696.3 examples/second
# [Step=1350]	Loss=0.3626	acc=0.8737	6303.9 examples/second
# Test Loss=0.5257, Test acc=0.8359
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=0.3635	acc=0.8711	3109.1 examples/second
# [Step=1450]	Loss=0.3532	acc=0.8766	6618.3 examples/second
# [Step=1500]	Loss=0.3500	acc=0.8775	6505.7 examples/second
# [Step=1550]	Loss=0.3495	acc=0.8772	6579.8 examples/second
# Test Loss=0.5446, Test acc=0.8282
#
# Epoch: 8
# [Step=1600]	Loss=0.3369	acc=0.8802	3163.0 examples/second
# [Step=1650]	Loss=0.3402	acc=0.8808	6417.0 examples/second
# [Step=1700]	Loss=0.3346	acc=0.8830	6440.0 examples/second
# [Step=1750]	Loss=0.3345	acc=0.8831	6491.9 examples/second
# Test Loss=0.5117, Test acc=0.8407
# Saving...
#
# Epoch: 9
# [Step=1800]	Loss=0.3286	acc=0.8842	3138.9 examples/second
# [Step=1850]	Loss=0.3329	acc=0.8807	6678.3 examples/second
# [Step=1900]	Loss=0.3289	acc=0.8827	6620.5 examples/second
# [Step=1950]	Loss=0.3280	acc=0.8835	6350.0 examples/second
# Test Loss=0.5237, Test acc=0.8447
# Saving...
#
# Epoch: 10
# [Step=2000]	Loss=0.3182	acc=0.8857	3161.0 examples/second
# [Step=2050]	Loss=0.3213	acc=0.8869	6632.7 examples/second
# [Step=2100]	Loss=0.3204	acc=0.8875	6462.2 examples/second
# [Step=2150]	Loss=0.3200	acc=0.8879	6437.9 examples/second
# Test Loss=0.4937, Test acc=0.8481
# Saving...
#
# Epoch: 11
# [Step=2200]	Loss=0.3300	acc=0.8828	3199.1 examples/second
# [Step=2250]	Loss=0.3254	acc=0.8846	6224.6 examples/second
# [Step=2300]	Loss=0.3189	acc=0.8876	6678.6 examples/second
# [Step=2350]	Loss=0.3162	acc=0.8887	6749.2 examples/second
# Test Loss=0.5492, Test acc=0.8366
#
# Epoch: 12
# [Step=2400]	Loss=0.3082	acc=0.8905	3136.0 examples/second
# [Step=2450]	Loss=0.3117	acc=0.8897	6453.2 examples/second
# [Step=2500]	Loss=0.3079	acc=0.8915	6222.4 examples/second
# Test Loss=0.5722, Test acc=0.8254
#
# Epoch: 13
# [Step=2550]	Loss=0.2648	acc=0.9082	3214.3 examples/second
# [Step=2600]	Loss=0.3124	acc=0.8911	6575.0 examples/second
# [Step=2650]	Loss=0.3075	acc=0.8919	6577.7 examples/second
# [Step=2700]	Loss=0.3063	acc=0.8921	6582.7 examples/second
# Test Loss=0.4843, Test acc=0.8476
#
# Epoch: 14
# [Step=2750]	Loss=0.3017	acc=0.8945	3185.8 examples/second
# [Step=2800]	Loss=0.3139	acc=0.8905	6733.7 examples/second
# [Step=2850]	Loss=0.3085	acc=0.8923	6609.5 examples/second
# [Step=2900]	Loss=0.3059	acc=0.8932	6441.2 examples/second
# Test Loss=0.5738, Test acc=0.8279
#
# Epoch: 15
# [Step=2950]	Loss=0.2872	acc=0.8918	3287.4 examples/second
# [Step=3000]	Loss=0.2909	acc=0.8974	6571.5 examples/second
# [Step=3050]	Loss=0.2949	acc=0.8964	6605.4 examples/second
# [Step=3100]	Loss=0.2935	acc=0.8970	6693.5 examples/second
# Test Loss=0.5502, Test acc=0.8364
#
# Epoch: 16
# [Step=3150]	Loss=0.3170	acc=0.8881	3208.7 examples/second
# [Step=3200]	Loss=0.2949	acc=0.8969	6544.7 examples/second
# [Step=3250]	Loss=0.2931	acc=0.8967	6570.7 examples/second
# [Step=3300]	Loss=0.2934	acc=0.8962	6621.6 examples/second
# Test Loss=0.4934, Test acc=0.8510
# Saving...
#
# Epoch: 17
# [Step=3350]	Loss=0.2758	acc=0.9032	3215.8 examples/second
# [Step=3400]	Loss=0.2842	acc=0.9001	6629.0 examples/second
# [Step=3450]	Loss=0.2876	acc=0.8992	6570.3 examples/second
# [Step=3500]	Loss=0.2866	acc=0.8993	6588.0 examples/second
# Test Loss=0.4964, Test acc=0.8461
#
# Epoch: 18
# [Step=3550]	Loss=0.2851	acc=0.8968	3052.1 examples/second
# [Step=3600]	Loss=0.2790	acc=0.9005	6272.8 examples/second
# [Step=3650]	Loss=0.2829	acc=0.8994	6194.3 examples/second
# [Step=3700]	Loss=0.2836	acc=0.8994	6661.7 examples/second
# Test Loss=0.5838, Test acc=0.8268
#
# Epoch: 19
# [Step=3750]	Loss=0.2871	acc=0.8987	3189.1 examples/second
# [Step=3800]	Loss=0.2867	acc=0.9000	6555.6 examples/second
# [Step=3850]	Loss=0.2843	acc=0.9003	5813.0 examples/second
# [Step=3900]	Loss=0.2786	acc=0.9029	5803.6 examples/second
# Test Loss=0.5159, Test acc=0.8448
# Files already downloaded and verified
# Test Loss=0.4934, Test accuracy=0.8510
# --------------------------------------------------

# %% [markdown]
# ### Lab3 (d) Quantize pruned model

# %%
all_nbits = [4, 3, 2]

for Nbits in all_nbits:
    print("Nbits: ", Nbits)
    net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
    net = net.to(device)
    net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))
    print("Loss and Test Accuracy Before Quantization")
    test(net)
    # Quantized model finetuning
    finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)
    # Load the model with best accuracy
    net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
    test(net)
    print("-"*50)
# Out:
# Nbits:  4
# Loss and Test Accuracy Before Quantization
# Files already downloaded and verified
# Test Loss=0.3653, Test accuracy=0.8848
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=0.7158	acc=0.8113	5923.7 examples/second
# [Step=100]	Loss=0.5570	acc=0.8462	6674.0 examples/second
# [Step=150]	Loss=0.4679	acc=0.8662	6353.9 examples/second
# Test Loss=0.3831, Test acc=0.8753
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.2644	acc=0.9033	3214.2 examples/second
# [Step=250]	Loss=0.2307	acc=0.9209	6402.6 examples/second
# [Step=300]	Loss=0.2253	acc=0.9247	6646.6 examples/second
# [Step=350]	Loss=0.2219	acc=0.9256	6520.7 examples/second
# Test Loss=0.4127, Test acc=0.8756
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.2147	acc=0.9355	3194.2 examples/second
# [Step=450]	Loss=0.2112	acc=0.9285	6553.2 examples/second
# [Step=500]	Loss=0.2091	acc=0.9297	6566.1 examples/second
# [Step=550]	Loss=0.2040	acc=0.9303	6629.2 examples/second
# Test Loss=0.3677, Test acc=0.8856
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.1826	acc=0.9336	3185.7 examples/second
# [Step=650]	Loss=0.1811	acc=0.9345	6539.7 examples/second
# [Step=700]	Loss=0.1858	acc=0.9333	6629.6 examples/second
# [Step=750]	Loss=0.1831	acc=0.9347	6451.2 examples/second
# Test Loss=0.3573, Test acc=0.8877
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=0.1816	acc=0.9373	3225.0 examples/second
# [Step=850]	Loss=0.1834	acc=0.9361	6469.9 examples/second
# [Step=900]	Loss=0.1811	acc=0.9370	6432.3 examples/second
# [Step=950]	Loss=0.1750	acc=0.9391	6611.5 examples/second
# Test Loss=0.3351, Test acc=0.8922
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.1537	acc=0.9467	3230.9 examples/second
# [Step=1050]	Loss=0.1590	acc=0.9448	6478.8 examples/second
# [Step=1100]	Loss=0.1586	acc=0.9437	6642.6 examples/second
# [Step=1150]	Loss=0.1553	acc=0.9449	6602.7 examples/second
# Test Loss=0.3483, Test acc=0.8933
# Saving...
#
# Epoch: 6
# [Step=1200]	Loss=0.1428	acc=0.9481	3190.3 examples/second
# [Step=1250]	Loss=0.1396	acc=0.9506	6594.1 examples/second
# [Step=1300]	Loss=0.1398	acc=0.9504	6626.8 examples/second
# [Step=1350]	Loss=0.1396	acc=0.9505	6620.7 examples/second
# Test Loss=0.3323, Test acc=0.8993
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=0.1307	acc=0.9530	3233.0 examples/second
# [Step=1450]	Loss=0.1354	acc=0.9517	5799.1 examples/second
# [Step=1500]	Loss=0.1350	acc=0.9521	6672.2 examples/second
# [Step=1550]	Loss=0.1340	acc=0.9529	6650.8 examples/second
# Test Loss=0.3503, Test acc=0.8997
# Saving...
#
# Epoch: 8
# [Step=1600]	Loss=0.1349	acc=0.9550	3174.9 examples/second
# [Step=1650]	Loss=0.1310	acc=0.9554	6653.9 examples/second
# [Step=1700]	Loss=0.1307	acc=0.9545	6280.1 examples/second
# [Step=1750]	Loss=0.1310	acc=0.9547	6525.3 examples/second
# Test Loss=0.3430, Test acc=0.8994
#
# Epoch: 9
# [Step=1800]	Loss=0.1198	acc=0.9566	3233.7 examples/second
# [Step=1850]	Loss=0.1227	acc=0.9554	6565.8 examples/second
# [Step=1900]	Loss=0.1233	acc=0.9562	6580.1 examples/second
# [Step=1950]	Loss=0.1249	acc=0.9558	6458.8 examples/second
# Test Loss=0.3383, Test acc=0.9012
# Saving...
#
# Epoch: 10
# [Step=2000]	Loss=0.1209	acc=0.9593	3169.0 examples/second
# [Step=2050]	Loss=0.1225	acc=0.9582	6631.3 examples/second
# [Step=2100]	Loss=0.1252	acc=0.9569	6019.2 examples/second
# [Step=2150]	Loss=0.1249	acc=0.9571	6015.2 examples/second
# Test Loss=0.3380, Test acc=0.9012
#
# Epoch: 11
# [Step=2200]	Loss=0.1232	acc=0.9588	3174.3 examples/second
# [Step=2250]	Loss=0.1268	acc=0.9575	6682.2 examples/second
# [Step=2300]	Loss=0.1236	acc=0.9580	6213.3 examples/second
# [Step=2350]	Loss=0.1243	acc=0.9573	6066.7 examples/second
# Test Loss=0.3564, Test acc=0.8984
#
# Epoch: 12
# [Step=2400]	Loss=0.1244	acc=0.9587	3124.3 examples/second
# [Step=2450]	Loss=0.1232	acc=0.9577	6634.7 examples/second
# [Step=2500]	Loss=0.1233	acc=0.9575	6660.8 examples/second
# Test Loss=0.3222, Test acc=0.9022
# Saving...
#
# Epoch: 13
# [Step=2550]	Loss=0.1304	acc=0.9512	3124.0 examples/second
# [Step=2600]	Loss=0.1198	acc=0.9581	6362.0 examples/second
# [Step=2650]	Loss=0.1191	acc=0.9583	6537.9 examples/second
# [Step=2700]	Loss=0.1188	acc=0.9585	6730.6 examples/second
# Test Loss=0.3584, Test acc=0.8989
#
# Epoch: 14
# [Step=2750]	Loss=0.1195	acc=0.9609	3193.7 examples/second
# [Step=2800]	Loss=0.1176	acc=0.9586	6427.1 examples/second
# [Step=2850]	Loss=0.1158	acc=0.9587	6195.0 examples/second
# [Step=2900]	Loss=0.1175	acc=0.9583	6720.9 examples/second
# Test Loss=0.3280, Test acc=0.9000
#
# Epoch: 15
# [Step=2950]	Loss=0.1057	acc=0.9578	3259.1 examples/second
# [Step=3000]	Loss=0.1143	acc=0.9598	6576.8 examples/second
# [Step=3050]	Loss=0.1140	acc=0.9600	6579.9 examples/second
# [Step=3100]	Loss=0.1132	acc=0.9604	6716.0 examples/second
# Test Loss=0.3420, Test acc=0.8962
#
# Epoch: 16
# [Step=3150]	Loss=0.1247	acc=0.9534	3202.6 examples/second
# [Step=3200]	Loss=0.1167	acc=0.9591	6485.5 examples/second
# [Step=3250]	Loss=0.1139	acc=0.9592	6652.7 examples/second
# [Step=3300]	Loss=0.1130	acc=0.9600	6689.6 examples/second
# Test Loss=0.3475, Test acc=0.9014
#
# Epoch: 17
# [Step=3350]	Loss=0.1012	acc=0.9648	3198.0 examples/second
# [Step=3400]	Loss=0.1081	acc=0.9612	6458.6 examples/second
# [Step=3450]	Loss=0.1111	acc=0.9600	6581.3 examples/second
# [Step=3500]	Loss=0.1135	acc=0.9594	6647.0 examples/second
# Test Loss=0.3243, Test acc=0.9016
#
# Epoch: 18
# [Step=3550]	Loss=0.1004	acc=0.9648	3151.6 examples/second
# [Step=3600]	Loss=0.1060	acc=0.9640	6577.5 examples/second
# [Step=3650]	Loss=0.1051	acc=0.9647	6425.6 examples/second
# [Step=3700]	Loss=0.1047	acc=0.9644	6573.7 examples/second
# Test Loss=0.3412, Test acc=0.9002
#
# Epoch: 19
# [Step=3750]	Loss=0.0991	acc=0.9642	3179.9 examples/second
# [Step=3800]	Loss=0.0984	acc=0.9650	6291.4 examples/second
# [Step=3850]	Loss=0.1039	acc=0.9633	6562.3 examples/second
# [Step=3900]	Loss=0.1035	acc=0.9634	6669.0 examples/second
# Test Loss=0.3342, Test acc=0.9029
# Saving...
# Files already downloaded and verified
# Test Loss=0.3342, Test accuracy=0.9029
# --------------------------------------------------
# Nbits:  3
# Loss and Test Accuracy Before Quantization
# Files already downloaded and verified
# Test Loss=1.1602, Test accuracy=0.6289
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=1.4477	acc=0.5549	5581.0 examples/second
# [Step=100]	Loss=1.1514	acc=0.6336	6236.6 examples/second
# [Step=150]	Loss=0.9769	acc=0.6829	6622.6 examples/second
# Test Loss=0.6015, Test acc=0.7960
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.5412	acc=0.8135	3192.0 examples/second
# [Step=250]	Loss=0.4952	acc=0.8277	6683.3 examples/second
# [Step=300]	Loss=0.4730	acc=0.8353	6647.6 examples/second
# [Step=350]	Loss=0.4568	acc=0.8413	6525.5 examples/second
# Test Loss=0.5119, Test acc=0.8287
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.3868	acc=0.8608	3238.4 examples/second
# [Step=450]	Loss=0.3806	acc=0.8669	6338.4 examples/second
# [Step=500]	Loss=0.3759	acc=0.8694	6608.5 examples/second
# [Step=550]	Loss=0.3660	acc=0.8742	6625.1 examples/second
# Test Loss=0.4720, Test acc=0.8413
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.3634	acc=0.8727	3199.0 examples/second
# [Step=650]	Loss=0.3344	acc=0.8850	6478.6 examples/second
# [Step=700]	Loss=0.3311	acc=0.8870	6590.0 examples/second
# [Step=750]	Loss=0.3295	acc=0.8868	6644.9 examples/second
# Test Loss=0.4615, Test acc=0.8470
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=0.3325	acc=0.8818	3174.1 examples/second
# [Step=850]	Loss=0.3077	acc=0.8928	6548.2 examples/second
# [Step=900]	Loss=0.3071	acc=0.8935	6703.8 examples/second
# [Step=950]	Loss=0.3067	acc=0.8935	6479.5 examples/second
# Test Loss=0.4284, Test acc=0.8572
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.2919	acc=0.8996	3171.3 examples/second
# [Step=1050]	Loss=0.2931	acc=0.8973	6638.1 examples/second
# [Step=1100]	Loss=0.2939	acc=0.8967	6544.6 examples/second
# [Step=1150]	Loss=0.2901	acc=0.8978	6532.2 examples/second
# Test Loss=0.4364, Test acc=0.8563
#
# Epoch: 6
# [Step=1200]	Loss=0.2723	acc=0.9046	3210.6 examples/second
# [Step=1250]	Loss=0.2755	acc=0.9048	6721.6 examples/second
# [Step=1300]	Loss=0.2736	acc=0.9059	6604.4 examples/second
# [Step=1350]	Loss=0.2791	acc=0.9034	6316.6 examples/second
# Test Loss=0.4098, Test acc=0.8678
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=0.2669	acc=0.9035	3169.8 examples/second
# [Step=1450]	Loss=0.2598	acc=0.9082	6543.1 examples/second
# [Step=1500]	Loss=0.2608	acc=0.9089	6608.5 examples/second
# [Step=1550]	Loss=0.2573	acc=0.9100	6565.5 examples/second
# Test Loss=0.4044, Test acc=0.8686
# Saving...
#
# Epoch: 8
# [Step=1600]	Loss=0.2607	acc=0.9087	3181.6 examples/second
# [Step=1650]	Loss=0.2568	acc=0.9098	6416.0 examples/second
# [Step=1700]	Loss=0.2544	acc=0.9114	6663.0 examples/second
# [Step=1750]	Loss=0.2499	acc=0.9126	6553.5 examples/second
# Test Loss=0.3959, Test acc=0.8719
# Saving...
#
# Epoch: 9
# [Step=1800]	Loss=0.2406	acc=0.9146	3164.6 examples/second
# [Step=1850]	Loss=0.2432	acc=0.9147	6663.1 examples/second
# [Step=1900]	Loss=0.2419	acc=0.9158	6555.4 examples/second
# [Step=1950]	Loss=0.2382	acc=0.9169	6621.7 examples/second
# Test Loss=0.4036, Test acc=0.8703
#
# Epoch: 10
# [Step=2000]	Loss=0.2473	acc=0.9100	3179.4 examples/second
# [Step=2050]	Loss=0.2407	acc=0.9141	6643.9 examples/second
# [Step=2100]	Loss=0.2375	acc=0.9159	6613.1 examples/second
# [Step=2150]	Loss=0.2347	acc=0.9172	6535.0 examples/second
# Test Loss=0.3850, Test acc=0.8754
# Saving...
#
# Epoch: 11
# [Step=2200]	Loss=0.2282	acc=0.9218	3121.6 examples/second
# [Step=2250]	Loss=0.2252	acc=0.9228	6540.9 examples/second
# [Step=2300]	Loss=0.2275	acc=0.9218	6728.1 examples/second
# [Step=2350]	Loss=0.2262	acc=0.9217	6431.4 examples/second
# Test Loss=0.3847, Test acc=0.8784
# Saving...
#
# Epoch: 12
# [Step=2400]	Loss=0.2165	acc=0.9235	3180.2 examples/second
# [Step=2450]	Loss=0.2196	acc=0.9220	6401.6 examples/second
# [Step=2500]	Loss=0.2188	acc=0.9221	6585.1 examples/second
# Test Loss=0.3834, Test acc=0.8772
#
# Epoch: 13
# [Step=2550]	Loss=0.1682	acc=0.9395	3230.6 examples/second
# [Step=2600]	Loss=0.2131	acc=0.9239	6655.4 examples/second
# [Step=2650]	Loss=0.2181	acc=0.9233	6624.1 examples/second
# [Step=2700]	Loss=0.2188	acc=0.9234	6596.1 examples/second
# Test Loss=0.3694, Test acc=0.8807
# Saving...
#
# Epoch: 14
# [Step=2750]	Loss=0.2162	acc=0.9225	3263.8 examples/second
# [Step=2800]	Loss=0.2086	acc=0.9260	6470.3 examples/second
# [Step=2850]	Loss=0.2077	acc=0.9273	6637.1 examples/second
# [Step=2900]	Loss=0.2105	acc=0.9263	6415.4 examples/second
# Test Loss=0.3896, Test acc=0.8776
#
# Epoch: 15
# [Step=2950]	Loss=0.2150	acc=0.9266	3192.7 examples/second
# [Step=3000]	Loss=0.2164	acc=0.9242	6655.0 examples/second
# [Step=3050]	Loss=0.2128	acc=0.9250	6560.3 examples/second
# [Step=3100]	Loss=0.2097	acc=0.9263	6558.8 examples/second
# Test Loss=0.3756, Test acc=0.8800
#
# Epoch: 16
# [Step=3150]	Loss=0.2158	acc=0.9263	3178.4 examples/second
# [Step=3200]	Loss=0.2058	acc=0.9278	6575.8 examples/second
# [Step=3250]	Loss=0.2062	acc=0.9283	6426.1 examples/second
# [Step=3300]	Loss=0.2057	acc=0.9281	6387.4 examples/second
# Test Loss=0.3720, Test acc=0.8814
# Saving...
#
# Epoch: 17
# [Step=3350]	Loss=0.2156	acc=0.9249	3192.6 examples/second
# [Step=3400]	Loss=0.2035	acc=0.9285	6513.9 examples/second
# [Step=3450]	Loss=0.2026	acc=0.9282	6752.2 examples/second
# [Step=3500]	Loss=0.2009	acc=0.9289	6576.7 examples/second
# Test Loss=0.3737, Test acc=0.8819
# Saving...
#
# Epoch: 18
# [Step=3550]	Loss=0.2057	acc=0.9288	3178.3 examples/second
# [Step=3600]	Loss=0.2004	acc=0.9305	6473.8 examples/second
# [Step=3650]	Loss=0.1986	acc=0.9315	6521.1 examples/second
# [Step=3700]	Loss=0.1958	acc=0.9318	6603.2 examples/second
# Test Loss=0.3762, Test acc=0.8813
#
# Epoch: 19
# [Step=3750]	Loss=0.1828	acc=0.9360	3201.5 examples/second
# [Step=3800]	Loss=0.1848	acc=0.9343	6647.7 examples/second
# [Step=3850]	Loss=0.1888	acc=0.9333	6460.3 examples/second
# [Step=3900]	Loss=0.1893	acc=0.9328	6497.2 examples/second
# Test Loss=0.3696, Test acc=0.8816
# Files already downloaded and verified
# Test Loss=0.3737, Test accuracy=0.8819
# --------------------------------------------------
# Nbits:  2
# Loss and Test Accuracy Before Quantization
# Files already downloaded and verified
# Test Loss=8868.3287, Test accuracy=0.1000
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=2.2615	acc=0.1442	5628.2 examples/second
# [Step=100]	Loss=2.2230	acc=0.1551	6597.1 examples/second
# [Step=150]	Loss=2.2022	acc=0.1642	6609.4 examples/second
# Test Loss=2.1514, Test acc=0.1763
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=2.1377	acc=0.1875	3207.4 examples/second
# [Step=250]	Loss=2.1291	acc=0.1892	6535.0 examples/second
# [Step=300]	Loss=2.1204	acc=0.1997	6461.9 examples/second
# [Step=350]	Loss=2.1145	acc=0.2070	6526.5 examples/second
# Test Loss=2.0970, Test acc=0.2225
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=2.1025	acc=0.2290	3218.3 examples/second
# [Step=450]	Loss=2.0873	acc=0.2289	6579.6 examples/second
# [Step=500]	Loss=2.0827	acc=0.2317	6557.9 examples/second
# [Step=550]	Loss=2.0790	acc=0.2330	6568.3 examples/second
# Test Loss=2.0861, Test acc=0.2292
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=2.0504	acc=0.2448	3236.7 examples/second
# [Step=650]	Loss=2.0549	acc=0.2441	6482.5 examples/second
# [Step=700]	Loss=2.0499	acc=0.2461	6625.0 examples/second
# [Step=750]	Loss=2.0458	acc=0.2489	6718.1 examples/second
# Test Loss=2.0295, Test acc=0.2607
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=2.0181	acc=0.2649	3177.6 examples/second
# [Step=850]	Loss=2.0247	acc=0.2560	6703.6 examples/second
# [Step=900]	Loss=2.0225	acc=0.2578	6515.6 examples/second
# [Step=950]	Loss=2.0189	acc=0.2602	6659.6 examples/second
# Test Loss=2.0186, Test acc=0.2604
#
# Epoch: 5
# [Step=1000]	Loss=2.0056	acc=0.2613	3180.8 examples/second
# [Step=1050]	Loss=2.0088	acc=0.2602	6698.2 examples/second
# [Step=1100]	Loss=2.0042	acc=0.2639	6604.8 examples/second
# [Step=1150]	Loss=2.0020	acc=0.2658	6550.4 examples/second
# Test Loss=2.0213, Test acc=0.2642
# Saving...
#
# Epoch: 6
# [Step=1200]	Loss=1.9738	acc=0.2699	3193.6 examples/second
# [Step=1250]	Loss=1.9852	acc=0.2754	6641.7 examples/second
# [Step=1300]	Loss=1.9828	acc=0.2760	6525.1 examples/second
# [Step=1350]	Loss=1.9804	acc=0.2746	6610.4 examples/second
# Test Loss=1.9805, Test acc=0.2808
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=1.9644	acc=0.2713	3219.4 examples/second
# [Step=1450]	Loss=1.9654	acc=0.2755	6569.0 examples/second
# [Step=1500]	Loss=1.9647	acc=0.2758	6578.8 examples/second
# [Step=1550]	Loss=1.9626	acc=0.2778	6329.8 examples/second
# Test Loss=1.9394, Test acc=0.2946
# Saving...
#
# Epoch: 8
# [Step=1600]	Loss=1.9392	acc=0.2850	3237.2 examples/second
# [Step=1650]	Loss=1.9400	acc=0.2847	6268.2 examples/second
# [Step=1700]	Loss=1.9384	acc=0.2864	6531.6 examples/second
# [Step=1750]	Loss=1.9364	acc=0.2878	6492.6 examples/second
# Test Loss=1.9080, Test acc=0.3030
# Saving...
#
# Epoch: 9
# [Step=1800]	Loss=1.9146	acc=0.2963	3232.4 examples/second
# [Step=1850]	Loss=1.9151	acc=0.2949	6723.1 examples/second
# [Step=1900]	Loss=1.9118	acc=0.2944	6513.6 examples/second
# [Step=1950]	Loss=1.9091	acc=0.2957	6597.4 examples/second
# Test Loss=1.9530, Test acc=0.2822
#
# Epoch: 10
# [Step=2000]	Loss=1.8857	acc=0.3053	3176.0 examples/second
# [Step=2050]	Loss=1.8797	acc=0.3069	6678.0 examples/second
# [Step=2100]	Loss=1.8826	acc=0.3043	6788.2 examples/second
# [Step=2150]	Loss=1.8819	acc=0.3051	6421.6 examples/second
# Test Loss=1.8762, Test acc=0.3079
# Saving...
#
# Epoch: 11
# [Step=2200]	Loss=1.8673	acc=0.3117	3187.5 examples/second
# [Step=2250]	Loss=1.8649	acc=0.3132	6548.7 examples/second
# [Step=2300]	Loss=1.8619	acc=0.3123	6645.9 examples/second
# [Step=2350]	Loss=1.8565	acc=0.3139	6412.1 examples/second
# Test Loss=1.8972, Test acc=0.3073
#
# Epoch: 12
# [Step=2400]	Loss=1.8395	acc=0.3240	3175.0 examples/second
# [Step=2450]	Loss=1.8312	acc=0.3247	6587.8 examples/second
# [Step=2500]	Loss=1.8315	acc=0.3248	6435.4 examples/second
# Test Loss=1.8169, Test acc=0.3291
# Saving...
#
# Epoch: 13
# [Step=2550]	Loss=1.8064	acc=0.3223	3210.0 examples/second
# [Step=2600]	Loss=1.8101	acc=0.3290	6461.9 examples/second
# [Step=2650]	Loss=1.8042	acc=0.3294	6741.4 examples/second
# [Step=2700]	Loss=1.7981	acc=0.3335	6619.2 examples/second
# Test Loss=1.8340, Test acc=0.3179
#
# Epoch: 14
# [Step=2750]	Loss=1.7852	acc=0.3379	3196.9 examples/second
# [Step=2800]	Loss=1.8010	acc=0.3325	6636.6 examples/second
# [Step=2850]	Loss=1.7862	acc=0.3372	6524.2 examples/second
# [Step=2900]	Loss=1.7788	acc=0.3418	6623.1 examples/second
# Test Loss=1.8422, Test acc=0.3264
#
# Epoch: 15
# [Step=2950]	Loss=1.7642	acc=0.3359	3258.4 examples/second
# [Step=3000]	Loss=1.7626	acc=0.3454	6632.8 examples/second
# [Step=3050]	Loss=1.7571	acc=0.3472	6760.8 examples/second
# [Step=3100]	Loss=1.7537	acc=0.3490	6529.9 examples/second
# Test Loss=1.8692, Test acc=0.3166
#
# Epoch: 16
# [Step=3150]	Loss=1.7434	acc=0.3516	3225.8 examples/second
# [Step=3200]	Loss=1.7298	acc=0.3538	6268.1 examples/second
# [Step=3250]	Loss=1.7229	acc=0.3567	6677.0 examples/second
# [Step=3300]	Loss=1.7219	acc=0.3598	6684.4 examples/second
# Test Loss=1.7879, Test acc=0.3365
# Saving...
#
# Epoch: 17
# [Step=3350]	Loss=1.7004	acc=0.3691	3180.4 examples/second
# [Step=3400]	Loss=1.6968	acc=0.3669	6588.7 examples/second
# [Step=3450]	Loss=1.6978	acc=0.3672	6491.7 examples/second
# [Step=3500]	Loss=1.6979	acc=0.3673	6600.5 examples/second
# Test Loss=1.8353, Test acc=0.3390
# Saving...
#
# Epoch: 18
# [Step=3550]	Loss=1.6800	acc=0.3723	3188.7 examples/second
# [Step=3600]	Loss=1.6701	acc=0.3770	6564.5 examples/second
# [Step=3650]	Loss=1.6738	acc=0.3773	6427.1 examples/second
# [Step=3700]	Loss=1.6728	acc=0.3793	6610.2 examples/second
# Test Loss=1.7516, Test acc=0.3429
# Saving...
#
# Epoch: 19
# [Step=3750]	Loss=1.6516	acc=0.3936	3206.9 examples/second
# [Step=3800]	Loss=1.6526	acc=0.3872	6615.9 examples/second
# [Step=3850]	Loss=1.6508	acc=0.3852	6576.6 examples/second
# [Step=3900]	Loss=1.6538	acc=0.3845	6522.7 examples/second
# Test Loss=1.7737, Test acc=0.3505
# Saving...
# Files already downloaded and verified
# Test Loss=1.7737, Test accuracy=0.3505
# --------------------------------------------------

# %% [markdown]
# ### Lab3 (e) Symmetric quantization
# #### Implement symmetric quantization in FP_layers.py, and repeat the process in (b)

# %%
# check the performance of symmetric quantization with 6, 5, 4, 3, 2 bits

# Define quantized model and load weight

all_nbits = [6, 5, 4, 3, 2]

for Nbits in all_nbits:
    print("Nbits: ", Nbits)
    net = ResNetCIFAR(num_layers=20, Nbits=Nbits, symmetric = True)
    net = net.to(device)
    net.load_state_dict(torch.load("pretrained_model.pt"))
    test(net)
    print("-"*50)
# Out:
# Nbits:  6
# Files already downloaded and verified
# Test Loss=0.3276, Test accuracy=0.9133
# --------------------------------------------------
# Nbits:  5
# Files already downloaded and verified
# Test Loss=0.3418, Test accuracy=0.9071
# --------------------------------------------------
# Nbits:  4
# Files already downloaded and verified
# Test Loss=0.5689, Test accuracy=0.8531
# --------------------------------------------------
# Nbits:  3
# Files already downloaded and verified
# Test Loss=1.2511, Test accuracy=0.7151
# --------------------------------------------------
# Nbits:  2
# Files already downloaded and verified
# Test Loss=96.5350, Test accuracy=0.1000
# --------------------------------------------------
